# %%
import os
import glob
import pandas as pd 
import numpy as np
from basketball_reference_web_scraper import client
import pickle

# %%
dir_path = '../basketball-reference.com_Stats/Shooting/*.csv' 
paths = glob.glob(dir_path)

# %%
player_names = [os.path.splitext(os.path.basename(path))[0] for path in paths]

# %%
player_names
# Out:
# ['Aaron Brooks',
#  'Aaron Holiday',
#  'Aaron Nesmith',
#  'Al Horford',
#  'Aaron Wiggins',
#  'Al Jefferson',
#  'Alan Anderson',
#  'Al-Farouq Aminu',
#  'Alan Williams',
#  'Alec Burks',
#  'Aaron Gordon',
#  'Adreian Payne',
#  'Alex Caruso',
#  'Alexis Ajinca',
#  'Abdel Nader',
#  'Aleksej Pokusevski',
#  'Alex Abrines',
#  'Alex Len',
#  "Amar'e Stoudemire",
#  'Amir Johnson',
#  'Amir Coffey',
#  'Andre Drummond',
#  'Andrea Bargnani',
#  'Alperen Sengun',
#  'Alonzo Gee',
#  'Allen Crabbe',
#  'Andre Roberson',
#  'Andrew Bogut',
#  'Andrew Harrison',
#  'Andrew Nembhard',
#  'Andrew Nicholson',
#  'Andrew Wiggins',
#  'Anthony Davis',
#  'Andre Iguodala',
#  'Anfernee Simons',
#  'Anthony Brown',
#  'Anthony Edwards',
#  'Anthony Gill',
#  'Anthony Morrow',
#  'Anthony Tolliver',
#  'Archie Goodwin',
#  'Armoni Brooks',
#  'Aron Baynes',
#  'Arron Afflalo',
#  'Austin Reaves',
#  'Austin Rivers',
#  'Avery Bradley',
#  'Ayo Dosunmu',
#  'Axel Toupane',
#  'Bam Adebayo',
# ...

# %%
player_heights = {'Aaron Gordon': 203,
                  'Aaron Brooks': 183,
                  'Al Jefferson': 208,
                  'Aaron Nesmith': 196,
                  'Aaron Wiggins': 198,
                  'Adreian Payne': 208,
                  'Al-Farouq Aminu': 203,
                  'Alan Anderson': 198,
                  'Alan Williams': 203,
                  'Alec Burks': 198,
                  'Alex Abrines': 198,
                  'Alex Caruso': 196,
                  'Aaron Holiday': 183,
                  'Abdel Nader': 196,
                  'Allen Crabbe': 196,
                  'Aleksej Pokusevski': 213,
                  'Alonzo Gee': 198,
                  "Amar'e Stoudemire": 208,
                  'Amir Johnson': 206,
                  'Alperen Sengun': 211,
                  'Al Horford': 206,
                  'Alexis Ajinca': 218,
                  'Alex Len': 213,
                  'Amir Coffey': 201,
                  'Andre Drummond': 211,
                  'Andre Roberson': 201,
                  'Andre Iguodala': 198,
                  'Andrea Bargnani': 213,
                  'Andrew Bogut': 213,
                  'Andrew Harrison': 198,
                  'Andrew Nicholson': 206,
                  'Andrew Wiggins': 201,
                  'Anthony Brown': 201,
                  'Andrew Nembhard': 196,
                  'Anthony Davis': 208,
                  'Anfernee Simons': 190,
                  'Anthony Edwards': 193,
                  'Anthony Morrow': 196,
                  'Anthony Tolliver': 203,
                  'Archie Goodwin': 196,
                  'Anthony Gill': 201,
                  'Armoni Brooks': 190,
                  'Aron Baynes': 208,
                  'Arron Afflalo': 196,
                  'Austin Rivers': 193,
                  'Avery Bradley': 190,
                  'Austin Reaves': 196,
                  'Terry Rozier': 185,
                  'Thaddeus Young': 203,
                  'Thabo Sefolosha': 198,
                  'Thomas Robinson': 208,
                  'Thomas Bryant': 208,
                  'Tiago Splitter': 211,
                  'Tim Duncan': 211,
                  'Tim Hardaway Jr.': 196,
                  'Tim Frazier': 183,
                  'Theo Maledon': 193,
                  'Timofey Mozgov': 216,
                  'Tomas Satoransky': 201,
                  'Timothe Luwawu-Cabarrot': 201,
                  'Toney Douglas': 188,
                  'Tobias Harris': 203,
                  'Tony Bradley': 208,
                  'Tony Parker': 188,
                  'Tony Snell': 198,
                  'Tony Allen': 193,
                  'Tre Jones': 185,
                  'Torrey Craig': 201,
                  'Trae Young': 185,
                  'Tre Mann': 190,
                  'Trendon Watford': 206,
                  'Treveon Graham': 196,
                  'Trevor Ariza': 203,
                  'Trevor Booker': 203,
                  'Trey Lyles': 206,
                  'Trey Burke': 183,
                  'Troy Williams': 201,
                  'Trent Forrest': 193,
                  'Tristan Thompson': 206,
                  'Troy Brown Jr.': 198,
                  'Troy Daniels': 193,
                  'Ty Lawson': 180,
                  'Tyler Cavanaugh': 206,
                  'Trey Murphy III': 203,
                  'Tyler Ennis': 190,
                  'Tyler Dorsey': 196,
                  'Tyler Johnson': 190,
                  'Tyler Ulis': 178,
                  'Tyler Zeller': 213,
                  'Tyreke Evans': 198,
                  'Tyler Herro': 196,
                  'Tyrone Wallace': 196,
                  'Tyrese Maxey': 188,
                  'Tyson Chandler': 213,
                  'Tyrese Haliburton': 196,
                  'Victor Oladipo': 190,
                  'Tyus Jones': 185,
                  'Vince Carter': 198,
                  'Usman Garuba': 203,
                  'Wayne Ellington': 193,
                  'Vlatko Cancar': 203,
                  'Wayne Selden': 196,
                  'Walker Kessler': 213,
                  'Wes Iwundu': 198,
                  'Wendell Carter Jr.': 208,
                  'Wesley Johnson': 201,
                  'Wesley Matthews': 196,
                  'Willie Cauley-Stein': 213,
                  'Will Barton': 196,
                  'Willie Reed': 208,
                  'Willy Hernangomez': 211,
                  'Wilson Chandler': 203,
                  'Yogi Ferrell': 183,
                  'Zach Collins': 211,
                  'Zach LaVine': 196,
                  'Zach Randolph': 206,
                  'Zaza Pachulia': 211,
                  'Xavier Tillman': 203,
                  'Zion Williamson': 198,
                  'Zeke Nnaji': 206,
                  'Ziaire Williams': 206
                  }

# %%
player_heights_df = pd.concat([pd.DataFrame(player_heights.keys(), columns=["before"]), pd.DataFrame(player_heights.values(), columns=["Height"])], axis=1)

# %%
with open('../pickle_files/player_df_before_after.pkl', 'rb') as f:
    player_df_before_after = pickle.load(f)

# %%
before_after_height_df = pd.merge(player_df_before_after, player_heights_df, on="before", how="left")

# %%
columns = ["Season",
          "Age",
          "Team",
          "League", 
          "Position",
          "GP", 
          "MP",
          "FG%", 
          "Dist.",
          "%_FGA_2P",
          "%_FGA_0-3",
          "%_FGA_3-10",
          "%_FGA_10-16",
          "%_FGA_16-3P",
          "%_FGA_3P",
          "FG%_2P",
          "FG%_0-3",
          "FG%_3-10",
          "FG%_10-16",
          "FG%_16-3P",
          "FG%_3P",
          "%_FG_Ast'd_2P",
          "%_FG_Ast'd_3P",
          "Dunk_%_FGA",
          "Dunk_#",
          "Corner3P_%_FGA",
          "Corner3P%",
          "Heaves_Att.",
          "Heaves_#"]

# %%
shooting_stats_dict = {}
for i, path in enumerate(paths):
    shooting_stats_dict[player_names[i]] = pd.read_csv(path, header=0, names=columns)
    shooting_stats_dict[player_names[i]]["Height"] = player_heights[player_names[i]]

# %%
players_df = pd.DataFrame(columns=["Player",
                                   "Height",
                                   "FG%_2P",
                                   "FG%_3P",
                                   "%_FG_Ast'd_2P", 
                                   "%_FG_Ast'd_3P", 
                                   "Corner3P_%_FGA", 
                                   "Dunk_%_FGA",
                                   "%_FGA_0-3",
                                   "%_FGA_3-10",
                                   "%_FGA_10-3P",
                                   "%_FGA_3P"
                                   ])

for player, stats in shooting_stats_dict.items():
    dropped_stats = stats.drop_duplicates(subset="Season", keep="first")
    for i, row in dropped_stats.iterrows():
        dropped_stats.loc[i, "Player"] = player+str(row["Season"][-2:])
    dropped_stats["%_FGA_10-3P"] = dropped_stats["%_FGA_10-16"] + dropped_stats["%_FGA_16-3P"]
    shooting_features = dropped_stats[["Player",
                                        "Height",
                                        "FG%_2P",
                                        "FG%_3P",
                                        "%_FG_Ast'd_2P", 
                                        "%_FG_Ast'd_3P", 
                                        "Corner3P_%_FGA", 
                                        "Dunk_%_FGA",
                                        "%_FGA_0-3",
                                        "%_FGA_3-10",
                                        "%_FGA_10-3P",
                                        "%_FGA_3P"
                                        ]]
    players_df = pd.concat([players_df, shooting_features])
# Out:
# /tmp/ipykernel_1899601/3743858274.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropped_stats.loc[i, "Player"] = player+str(row["Season"][-2:])
# /tmp/ipykernel_1899601/3743858274.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropped_stats["%_FGA_10-3P"] = dropped_stats["%_FGA_10-16"] + dropped_stats["%_FGA_16-3P"]
# /tmp/ipykernel_1899601/3743858274.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
players_df[players_df["Player"]=="Nikola Jokic23"]
# Out:
#            Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 7  Nikola Jokic23    211   0.675   0.383          0.603          0.825
#
#    Corner3P_%_FGA Dunk_%_FGA  %_FGA_0-3  %_FGA_3-10  %_FGA_10-3P  %_FGA_3P
# 7           0.027      0.022      0.303       0.414         0.13     0.146

# %%
basic_stats = {}
advanced_stats = {}

for y in range(2013, 2024):
    basic_stats[y] = client.players_season_totals(season_end_year=y)
    advanced_stats[y] = client.players_advanced_season_totals(season_end_year=y)

# %%
advanced_features = pd.DataFrame(columns=["Player",
                                          "GP",
                                        "OR%",
                                        "DR%",
                                        "AST%",
                                        "STL%",
                                        "BLK%",
                                        "TO%",
                                        "Points",
                                        "USG%",
                                        "PER",
                                        "FTA%",
                                        "FT%",
                                        "FGAperposs",
                                        ])

# %%
for y in range(2013, 2024):
    GP_tmp = []
    PTS_tmp = []
    FGA_tmp = []
    FTA_tmp = 0
    TOV_tmp = 0
    OR_percentage_tmp = []
    DR_percentage_tmp = []
    AST_percentage_tmp = []
    STL_percentage_tmp = []
    BLK_percentage_tmp = []
    TO_percentage_tmp = []
    USG_percentage_tmp = []
    PER_tmp = []
    FTA_rate_tmp = []
    FTM_tmp = 0
    MP_tmp = []
    
    advanced_features_by_year = pd.DataFrame(columns=["Player",
                                                      "GP",
                                                      "OR%",
                                                      "DR%",
                                                      "AST%",
                                                      "STL%",
                                                      "BLK%",
                                                      "TO%",
                                                      "Points",
                                                      "USG%",
                                                      "PER",
                                                      "FTA%",
                                                      "FT%",
                                                      "FGAperposs",
                                                      ])
    for i in range(len(basic_stats[y])):
        print(i, basic_stats[y][i]["name"])
        GP_tmp.append(basic_stats[y][i]["games_played"])
        
        if i != len(basic_stats[y])-1:
            if basic_stats[y][i]["name"] == basic_stats[y][i+1]["name"]:
                PTS_tmp.append(basic_stats[y][i]["points"])
                FGA_tmp.append(basic_stats[y][i]["attempted_field_goals"])
                FTA_tmp += basic_stats[y][i]["attempted_free_throws"]
                TOV_tmp += basic_stats[y][i]["turnovers"]
                OR_percentage_tmp.append(advanced_stats[y][i]['offensive_rebound_percentage'])
                DR_percentage_tmp.append(advanced_stats[y][i]['defensive_rebound_percentage'])
                AST_percentage_tmp.append(advanced_stats[y][i]['assist_percentage'])
                STL_percentage_tmp.append(advanced_stats[y][i]['steal_percentage'])
                BLK_percentage_tmp.append(advanced_stats[y][i]['block_percentage'])
                TO_percentage_tmp.append(advanced_stats[y][i]['turnover_percentage'])
                USG_percentage_tmp.append(advanced_stats[y][i]['usage_percentage'])
                PER_tmp.append(advanced_stats[y][i]['player_efficiency_rating'])
                FTA_rate_tmp.append(advanced_stats[y][i]['free_throw_attempt_rate'])
                FTM_tmp += basic_stats[y][i]['made_free_throws']
                MP_tmp.append(basic_stats[y][i]['minutes_played'])
                continue
        
        advanced_features_by_player = []
        
        if len(GP_tmp) == 1:
            advanced_features_by_player.append(basic_stats[y][i]["name"]+str(y)[-2:])
            advanced_features_by_player.append(basic_stats[y][i]["games_played"])
            advanced_features_by_player.append(advanced_stats[y][i]['offensive_rebound_percentage'])
            advanced_features_by_player.append(advanced_stats[y][i]['defensive_rebound_percentage'])
            advanced_features_by_player.append(advanced_stats[y][i]['assist_percentage'])
            advanced_features_by_player.append(advanced_stats[y][i]['steal_percentage'])
            advanced_features_by_player.append(advanced_stats[y][i]['block_percentage'])
            advanced_features_by_player.append(advanced_stats[y][i]['turnover_percentage'])
            advanced_features_by_player.append(basic_stats[y][i]["points"]/(basic_stats[y][i]['minutes_played']*2+1e-8))
            advanced_features_by_player.append(advanced_stats[y][i]['usage_percentage'])
            advanced_features_by_player.append(advanced_stats[y][i]['player_efficiency_rating'])
            advanced_features_by_player.append(advanced_stats[y][i]['free_throw_attempt_rate'])
            advanced_features_by_player.append(basic_stats[y][i]['made_free_throws']/(basic_stats[y][i]['attempted_free_throws']+1e-8))
            advanced_features_by_player.append(basic_stats[y][i]['attempted_field_goals']/(basic_stats[y][i]['minutes_played']*2+1e-8))
        else:
            OR_percentage_tmp.append(advanced_stats[y][i]['offensive_rebound_percentage'])
            DR_percentage_tmp.append(advanced_stats[y][i]['defensive_rebound_percentage'])
            AST_percentage_tmp.append(advanced_stats[y][i]['assist_percentage'])
            STL_percentage_tmp.append(advanced_stats[y][i]['steal_percentage'])
            BLK_percentage_tmp.append(advanced_stats[y][i]['block_percentage'])
            TO_percentage_tmp.append(advanced_stats[y][i]['turnover_percentage'])
            PTS_tmp.append(basic_stats[y][i]["points"])
            USG_percentage_tmp.append(advanced_stats[y][i]['usage_percentage'])
            PER_tmp.append(advanced_stats[y][i]['player_efficiency_rating'])
            FTA_rate_tmp.append(advanced_stats[y][i]['free_throw_attempt_rate'])
            FTM_tmp += basic_stats[y][i]['made_free_throws']
            FGA_tmp.append(basic_stats[y][i]["attempted_field_goals"])
            MP_tmp.append(basic_stats[y][i]['minutes_played'])
            advanced_features_by_player.append(basic_stats[y][i]["name"]+str(y)[-2:])
            advanced_features_by_player.append(sum(GP_tmp))
            advanced_features_by_player.append(np.average(OR_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(DR_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(AST_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(STL_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(BLK_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(TO_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average([PTS_tmp[j]/(MP_tmp[j]*2+1e-8) for j in range(len(GP_tmp))], weights=GP_tmp))
            advanced_features_by_player.append(np.average(USG_percentage_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(PER_tmp, weights=GP_tmp))
            advanced_features_by_player.append(np.average(FTA_rate_tmp, weights=GP_tmp))
            advanced_features_by_player.append(FTM_tmp/(FTA_tmp+1e-8))
            print(len(FGA_tmp), len(MP_tmp), len(GP_tmp))
            advanced_features_by_player.append(np.average([FGA_tmp[j]/(MP_tmp[j]*2+1e-8) for j in range(len(GP_tmp))], weights=GP_tmp))
        
        
        advanced_features_by_player = pd.DataFrame(advanced_features_by_player)
        advanced_features_by_player = advanced_features_by_player.transpose()
        advanced_features_by_player.columns = advanced_features_by_year.columns
        advanced_features_by_year = pd.concat([advanced_features_by_year, advanced_features_by_player])
        
        GP_tmp = []
        PTS_tmp = []
        FGA_tmp = []
        FTA_tmp = 0
        TOV_tmp = 0
        OR_percentage_tmp = []
        DR_percentage_tmp = []
        AST_percentage_tmp = []
        STL_percentage_tmp = []
        BLK_percentage_tmp = []
        TO_percentage_tmp = []
        USG_percentage_tmp = []
        PER_tmp = []
        FTA_rate_tmp = []
        FTM_tmp = 0
        MP_tmp = []
    
    advanced_features = pd.concat([advanced_features, advanced_features_by_year])
# Out:
# 0 Quincy Acy
# 1 Jeff Adrien
# 2 Arron Afflalo
# 3 Josh Akognon
# 4 Cole Aldrich
# 5 Cole Aldrich
# 2 2 2
# 6 LaMarcus Aldridge
# 7 Lavoy Allen
# 8 Ray Allen
# 9 Tony Allen
# 10 Al-Farouq Aminu
# 11 Lou Amundson
# 12 Lou Amundson
# 13 Lou Amundson
# 3 3 3
# 14 Chris Andersen
# 15 Alan Anderson
# 16 James Anderson
# 17 James Anderson
# 2 2 2
# 18 Ryan Anderson
# 19 Carmelo Anthony
# 20 Joel Anthony
# 21 Trevor Ariza
# 22 Darrell Arthur
# 23 Ömer Aşık
# 24 D.J. Augustin
# 25 Gustavo Ayón
# 26 Gustavo Ayón
# 2 2 2
# 27 Jeff Ayres
# 28 Luke Babbitt
# 29 Leandro Barbosa
# 30 J.J. Barea
# 31 Andrea Bargnani
# 32 Harrison Barnes
# 33 Matt Barnes
# 34 Earl Barron
# 35 Earl Barron
# 2 2 2
# 36 Will Barton
# 37 Brandon Bass
# 38 Shane Battier
# 39 Nicolas Batum
# 40 Jerryd Bayless
# 41 Aron Baynes
# 42 Kent Bazemore
# 43 Bradley Beal
# 44 Michael Beasley
# 45 Rodrigue Beaubois
# 46 Marco Belinelli
# 47 Patrick Beverley
# 48 Andris Biedriņš
# 49 Chauncey Billups
# 50 Bismack Biyombo
# ...

# %%
for y in range(13, 24):
    advanced_features.replace("Nikola Vučević"+str(y), 'Nikola Vucevic'+str(y), inplace=True)
    advanced_features.replace("Jonas Valančiūnas"+str(y), 'Jonas Valanciunas'+str(y), inplace=True)
    advanced_features.replace("Alperen Şengün"+str(y), 'Alperen Sengun'+str(y), inplace=True)
    advanced_features.replace("Nikola Jokić"+str(y), 'Nikola Jokic'+str(y), inplace=True)
    advanced_features.replace("OG Anunoby"+str(y), 'O.G. Anunoby'+str(y), inplace=True)
    advanced_features.replace("Dennis Schröder"+str(y), 'Dennis Schroder'+str(y), inplace=True)
    advanced_features.replace("Luka Dončić"+str(y), 'Luka Doncic'+str(y), inplace=True)
    advanced_features.replace("Kristaps Porziņģis"+str(y), 'Kristaps Porzingis'+str(y), inplace=True)
    advanced_features.replace("Marcus Morris"+str(y), 'Marcus Morris Sr.'+str(y), inplace=True)
    advanced_features.replace("Kevin Knox"+str(y), 'Kevin Knox II'+str(y), inplace=True)
    advanced_features.replace("Xavier Tillman Sr."+str(y), 'Xavier Tillman'+str(y), inplace=True)
    advanced_features.replace("Vlatko Čančar"+str(y), 'Vlatko Cancar'+str(y), inplace=True)
    advanced_features.replace("Bojan Bogdanović"+str(y), 'Bojan Bogdanovic'+str(y), inplace=True)
    advanced_features.replace("Goran Dragić"+str(y), 'Goran Dragic'+str(y), inplace=True)
    advanced_features.replace("Dario Šarić"+str(y), 'Dario Saric'+str(y), inplace=True)
    advanced_features.replace("Bogdan Bogdanović"+str(y), 'Bogdan Bogdanovic'+str(y), inplace=True)
    advanced_features.replace("Jusuf Nurkić"+str(y), 'Jusuf Nurkic'+str(y), inplace=True)
    advanced_features.replace("Dāvis Bertāns"+str(y), 'Davis Bertans'+str(y), inplace=True)
    advanced_features.replace("Théo Maledon"+str(y), 'Theo Maledon'+str(y), inplace=True)
    advanced_features.replace("Juancho Hernangómez"+str(y), 'Juancho Hernangomez'+str(y), inplace=True)
    advanced_features.replace("Willy Hernangómez"+str(y), 'Willy Hernangomez'+str(y), inplace=True)
    advanced_features.replace("Robert Williams"+str(y), 'Robert Williams III'+str(y), inplace=True)

# %%
for y in range(13, 24):
    advanced_features.replace("Ersan İlyasova"+str(y), 'Ersan Ilyasova'+str(y), inplace=True)
    advanced_features.replace("José Calderón"+str(y), 'Jose Calderon'+str(y), inplace=True)
    advanced_features.replace("J.R. Smith"+str(y), 'JR Smith'+str(y), inplace=True)
    advanced_features.replace("J.J. Redick"+str(y), 'JJ Redick'+str(y), inplace=True)
    advanced_features.replace("C.J. Miles"+str(y), 'CJ Miles'+str(y), inplace=True)
    advanced_features.replace("Donatas Motiejūnas"+str(y), 'Donatas Motiejunas'+str(y), inplace=True)
    advanced_features.replace("P.J. Hairston"+str(y), 'PJ Hairston'+str(y), inplace=True)
    advanced_features.replace("Sasha Vujačić"+str(y), 'Sasha Vujacic'+str(y), inplace=True)
    advanced_features.replace("Nikola Mirotić"+str(y), 'Nikola Mirotic'+str(y), inplace=True)
    advanced_features.replace("Ömer Aşık"+str(y), 'Omer Asik'+str(y), inplace=True)
    advanced_features.replace("Manu Ginóbili"+str(y), 'Manu Ginobili'+str(y), inplace=True)
    advanced_features.replace("Kevin Séraphin"+str(y), 'Kevin Seraphin'+str(y), inplace=True)
    advanced_features.replace("Mirza Teletović"+str(y), 'Mirza Teletovic'+str(y), inplace=True)
    advanced_features.replace("Johnny O'Bryant"+str(y), "Johnny O'Bryant III"+str(y), inplace=True)
    advanced_features.replace("Nenê"+str(y), 'Nene'+str(y), inplace=True)
    advanced_features.replace("Álex Abrines"+str(y), 'Alex Abrines'+str(y), inplace=True)
    advanced_features.replace("Sergio Rodríguez"+str(y), 'Sergio Rodriguez'+str(y), inplace=True)
    advanced_features.replace("Timothé Luwawu-Cabarrot"+str(y), 'Timothe Luwawu-Cabarrot'+str(y), inplace=True)
    advanced_features.replace("Alexis Ajinça"+str(y), 'Alexis Ajinca'+str(y), inplace=True)
    advanced_features.replace("Tomáš Satoranský"+str(y), 'Tomas Satoransky'+str(y), inplace=True)
    advanced_features.replace("Cristiano Felício"+str(y), 'Cristiano Felicio'+str(y), inplace=True)
    advanced_features.replace("Skal Labissière"+str(y), 'Skal Labissiere'+str(y), inplace=True)
    advanced_features.replace("Miloš Teodosić"+str(y), 'Milos Teodosic'+str(y), inplace=True)
    advanced_features.replace("Boban Marjanović"+str(y), 'Boban Marjanovic'+str(y), inplace=True)
    advanced_features.replace("Harry Giles"+str(y), 'Harry Giles III'+str(y), inplace=True)
    advanced_features.replace("Džanan Musa"+str(y), 'Dzanan Musa'+str(y), inplace=True)
    advanced_features.replace("KJ Martin"+str(y), 'Kenyon Martin Jr.'+str(y), inplace=True)
    advanced_features.replace("Enes Freedom"+str(y), 'Enes Kanter'+str(y), inplace=True)
    advanced_features.replace("Greivis Vásquez"+str(y), 'Greivis Vasquez'+str(y), inplace=True)
    advanced_features.replace("J.J. Hickson"+str(y), 'JJ Hickson'+str(y), inplace=True)

# %%
advanced_features1 = advanced_features[advanced_features["GP"]>=9]
advanced_features2 = advanced_features[advanced_features["GP"]>=20]

# %%
kalman_features1 = pd.merge(players_df, advanced_features1.drop(columns="GP"), on="Player")
kalman_features1
# Out:
#                  Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0        Aaron Brooks13    183   0.511   0.373          0.215          0.640
# 1        Aaron Brooks14    183   0.411   0.387          0.139          0.698
# 2        Aaron Brooks15    183   0.442   0.387          0.126          0.612
# 3        Aaron Brooks16    183   0.430   0.357          0.090          0.576
# 4        Aaron Brooks17    183   0.424   0.375          0.096          0.583
# ...                 ...    ...     ...     ...            ...            ...
# 4069  Ziaire Williams22    206   0.632   0.314          0.800          0.961
# 4070  Ziaire Williams23    206   0.596   0.258          0.780          0.880
# 4071  Zion Williamson20    198   0.590   0.429          0.755          1.000
# 4072  Zion Williamson21    198   0.622   0.294          0.553          1.000
# 4073  Zion Williamson23    198   0.618   0.368          0.457          0.857
#
# ...

# %%
kalman_features2 = pd.merge(players_df, advanced_features2.drop(columns="GP"), on="Player")
kalman_features2
# Out:
#                  Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0        Aaron Brooks13    183   0.511   0.373          0.215          0.640
# 1        Aaron Brooks14    183   0.411   0.387          0.139          0.698
# 2        Aaron Brooks15    183   0.442   0.387          0.126          0.612
# 3        Aaron Brooks16    183   0.430   0.357          0.090          0.576
# 4        Aaron Brooks17    183   0.424   0.375          0.096          0.583
# ...                 ...    ...     ...     ...            ...            ...
# 3900  Ziaire Williams22    206   0.632   0.314          0.800          0.961
# 3901  Ziaire Williams23    206   0.596   0.258          0.780          0.880
# 3902  Zion Williamson20    198   0.590   0.429          0.755          1.000
# 3903  Zion Williamson21    198   0.622   0.294          0.553          1.000
# 3904  Zion Williamson23    198   0.618   0.368          0.457          0.857
#
# ...

# %%
kalman_features1.fillna(0, inplace=True)
kalman_features1.reset_index(inplace=True, drop=True)
kalman_features1
# Out:
#                  Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0        Aaron Brooks13    183   0.511   0.373          0.215          0.640
# 1        Aaron Brooks14    183   0.411   0.387          0.139          0.698
# 2        Aaron Brooks15    183   0.442   0.387          0.126          0.612
# 3        Aaron Brooks16    183   0.430   0.357          0.090          0.576
# 4        Aaron Brooks17    183   0.424   0.375          0.096          0.583
# ...                 ...    ...     ...     ...            ...            ...
# 4069  Ziaire Williams22    206   0.632   0.314          0.800          0.961
# 4070  Ziaire Williams23    206   0.596   0.258          0.780          0.880
# 4071  Zion Williamson20    198   0.590   0.429          0.755          1.000
# 4072  Zion Williamson21    198   0.622   0.294          0.553          1.000
# 4073  Zion Williamson23    198   0.618   0.368          0.457          0.857
#
# ...

# %%
kalman_features2.fillna(0, inplace=True)
kalman_features2.reset_index(inplace=True, drop=True)
kalman_features2
# Out:
#                  Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0        Aaron Brooks13    183   0.511   0.373          0.215          0.640
# 1        Aaron Brooks14    183   0.411   0.387          0.139          0.698
# 2        Aaron Brooks15    183   0.442   0.387          0.126          0.612
# 3        Aaron Brooks16    183   0.430   0.357          0.090          0.576
# 4        Aaron Brooks17    183   0.424   0.375          0.096          0.583
# ...                 ...    ...     ...     ...            ...            ...
# 3900  Ziaire Williams22    206   0.632   0.314          0.800          0.961
# 3901  Ziaire Williams23    206   0.596   0.258          0.780          0.880
# 3902  Zion Williamson20    198   0.590   0.429          0.755          1.000
# 3903  Zion Williamson21    198   0.622   0.294          0.553          1.000
# 3904  Zion Williamson23    198   0.618   0.368          0.457          0.857
#
# ...

# %%
kalman_features_1 = kalman_features1.query('Player.str.endswith("13") | Player.str.endswith("14") | Player.str.endswith("15") | Player.str.endswith("16") | Player.str.endswith("17") | Player.str.endswith("18") | Player.str.endswith("19")').reset_index(drop=True)
kalman_features_1
# Out:
#                Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0      Aaron Brooks13    183   0.511   0.373          0.215          0.640
# 1      Aaron Brooks14    183   0.411   0.387          0.139          0.698
# 2      Aaron Brooks15    183   0.442   0.387          0.126          0.612
# 3      Aaron Brooks16    183   0.430   0.357          0.090          0.576
# 4      Aaron Brooks17    183   0.424   0.375          0.096          0.583
# ...               ...    ...     ...     ...            ...            ...
# 2460  Zaza Pachulia15    211   0.456   0.000          0.742          0.000
# 2461  Zaza Pachulia16    211   0.469   0.000          0.680          0.000
# 2462  Zaza Pachulia17    211   0.538   0.000          0.805          0.000
# 2463  Zaza Pachulia18    211   0.567   0.000          0.819          0.000
# 2464  Zaza Pachulia19    211   0.450   0.000          0.624          0.000
#
# ...

# %%
kalman_features_2 = kalman_features2.query('Player.str.endswith("16") | Player.str.endswith("17") | Player.str.endswith("18") | Player.str.endswith("19") | Player.str.endswith("20") | Player.str.endswith("21") | Player.str.endswith("22") | Player.str.endswith("23")').reset_index(drop=True)
kalman_features_2
# Out:
#                  Player Height  FG%_2P  FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0        Aaron Brooks16    183   0.430   0.357          0.090          0.576
# 1        Aaron Brooks17    183   0.424   0.375          0.096          0.583
# 2        Aaron Brooks18    183   0.447   0.355          0.118          0.818
# 3       Aaron Holiday19    183   0.459   0.339          0.387          0.791
# 4       Aaron Holiday20    183   0.427   0.394          0.288          0.839
# ...                 ...    ...     ...     ...            ...            ...
# 3046  Ziaire Williams22    206   0.632   0.314          0.800          0.961
# 3047  Ziaire Williams23    206   0.596   0.258          0.780          0.880
# 3048  Zion Williamson20    198   0.590   0.429          0.755          1.000
# 3049  Zion Williamson21    198   0.622   0.294          0.553          1.000
# 3050  Zion Williamson23    198   0.618   0.368          0.457          0.857
#
# ...

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
scaler = StandardScaler()

# %%
scaled_values_2 = scaler.fit_transform(kalman_features_2.drop("Player", axis=1))
scaled_df_2 = pd.DataFrame(scaled_values_2, columns=kalman_features_2.columns[1:])
scaled_df_2
# Out:
#         Height    FG%_2P    FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0    -1.909054 -1.193729  0.354003      -2.294433      -0.746401
# 1    -1.909054 -1.277357  0.503171      -2.263616      -0.721965
# 2    -1.909054 -0.956783  0.337428      -2.150620       0.098384
# 3    -1.909054 -0.789527  0.204834      -0.768992       0.004132
# 4    -1.909054 -1.235543  0.660626      -1.277472       0.171692
# ...        ...       ...       ...            ...            ...
# 3046  0.753612  1.621745 -0.002344       1.352244       0.597576
# 3047  0.753612  1.119978 -0.466423       1.249521       0.314817
# 3048 -0.172533  1.036350  0.950676       1.121116       0.733719
# 3049 -0.172533  1.482366 -0.168087       0.083611       0.733719
# 3050 -0.172533  1.426614  0.445161      -0.409461       0.234528
#
#       Corner3P_%_FGA  Dunk_%_FGA  %_FGA_0-3  %_FGA_3-10  %_FGA_10-3P  ...  \
# 0          -0.909351   -0.743043  -0.344560    0.150858     0.083689  ...
# ...

# %%
gmm = GaussianMixture(n_components=9, random_state=2, covariance_type="tied")
gmm.fit(scaled_df_2)
labels = gmm.predict(scaled_df_2)
labels_df = pd.DataFrame(labels)
labeled_df = pd.concat([kalman_features_2['Player'], labels_df, scaled_df_2], axis=1)

# %%
cluster_names = ["Mid-range Big",
                 "Traditional Center_A",
                 "Flore General",
                 "High-usage Guard",
                 "Versatile Role-player",
                 "Rim Plotecter",
                 "Traditional Center_B",
                 "Stretch Forward",
                 "3-point Shooting-guard"
                 ]

# %%
membership_probability = gmm.predict_proba(scaled_df_2)
membership_probability
# Out:
# array([[4.99139637e-13, 6.07596002e-55, 6.39356988e-03, ...,
#         7.66591195e-16, 1.55331400e-10, 2.33671176e-03],
#        [7.21308447e-12, 9.93699853e-51, 2.36038346e-02, ...,
#         1.23793563e-13, 5.70690453e-09, 3.41612099e-02],
#        [5.79889995e-09, 7.93505663e-69, 4.11829299e-01, ...,
#         9.42033904e-11, 6.46799958e-06, 5.87887212e-01],
#        ...,
#        [1.06539501e-02, 3.16304922e-66, 3.05766582e-07, ...,
#         9.78020400e-01, 7.24275243e-06, 1.85971633e-05],
#        [4.18748057e-04, 1.08438138e-65, 5.23230150e-05, ...,
#         9.92506458e-01, 7.99237092e-07, 3.27809456e-05],
#        [7.31095752e-02, 1.71350142e-59, 1.98960184e-01, ...,
#         1.85475582e-01, 7.88040129e-05, 7.45291639e-02]])

# %%
players_clusters_df = pd.concat([kalman_features_2['Player'], 
                        pd.DataFrame(membership_probability, columns=cluster_names)],
                        axis=1)
players_clusters_df
# Out:
#                  Player  Mid-range Big  Traditional Center_A  Flore General  \
# 0        Aaron Brooks16   4.991396e-13          6.075960e-55   6.393570e-03
# 1        Aaron Brooks17   7.213084e-12          9.936999e-51   2.360383e-02
# 2        Aaron Brooks18   5.798900e-09          7.935057e-69   4.118293e-01
# 3       Aaron Holiday19   5.203848e-07          5.269413e-65   1.909841e-01
# 4       Aaron Holiday20   1.701168e-07          3.566934e-69   6.828013e-01
# ...                 ...            ...                   ...            ...
# 3046  Ziaire Williams22   3.171769e-07          7.710579e-64   3.431208e-08
# 3047  Ziaire Williams23   7.660520e-06          1.650860e-53   5.281415e-07
# 3048  Zion Williamson20   1.065395e-02          3.163049e-66   3.057666e-07
# 3049  Zion Williamson21   4.187481e-04          1.084381e-65   5.232301e-05
# 3050  Zion Williamson23   7.310958e-02          1.713501e-59   1.989602e-01
#
# ...

# %%
confusing_name_list = ["JaMychal Green", "Jeff Green", "Jalen Green", "Josh Green",
                        "Draymond Green", "Danny Green", 
                        "Stephen Curry", "Seth Curry", 
                        "Marcus Morris", "Markieff Morris", "Monte Morris",
                        "JR Smith", "Jason Smith", "Josh Smith", "Jalen Smith",
                        "James Johnson", "Joe Johnson",
                        "Deron Williams", "Derrick Williams",
                        "Marvin Williams", "Mo Williams",
                        "Trae Young", "Thaddeus Young",
                        "Jerami Grant", "Jerian Grant",
                        "Mason Plumlee", "Miles Plumlee",
                        "Justin Anderson", "James Anderson",
                        "Jrue Holiday", "Justin Holiday",
                        "Aaron Wiggins", "Andrew Wiggins",
                        "Bojan Bogdanovic", "Bogdan Bogdanovic",
                        "Josh Jackson", "Justin Jackson",
                        "Tyus Jones", "Tre Jones", "Terrence Jones",
                        "Miles Bridges", "Mikal Bridges",
                        "Cole Anthony", "Carmelo Anthony",
                        "Lonzo Ball", "LaMelo Ball",
                        "Jalen McDaniels", "Jaden McDaniels",
                        "Caleb Martin", "Cody Martin",
                        "Terance Mann", "Tre Mann",
                        "Donovan Mitchell", "Davion Mitchell",
                        "Keldon Johnson", "Keon Johnson",
                        "Malik Beasley", "Michael Beasley"
                        ]

# %%
confusing_name_year_list = []
for y in range(16,24):
    for confusing_name in confusing_name_list:
        confusing_name_year_list.append(confusing_name+str(y))
confusing_name_year_list
# Out:
# ['JaMychal Green16',
#  'Jeff Green16',
#  'Jalen Green16',
#  'Josh Green16',
#  'Draymond Green16',
#  'Danny Green16',
#  'Stephen Curry16',
#  'Seth Curry16',
#  'Marcus Morris16',
#  'Markieff Morris16',
#  'Monte Morris16',
#  'JR Smith16',
#  'Jason Smith16',
#  'Josh Smith16',
#  'Jalen Smith16',
#  'James Johnson16',
#  'Joe Johnson16',
#  'Deron Williams16',
#  'Derrick Williams16',
#  'Marvin Williams16',
#  'Mo Williams16',
#  'Trae Young16',
#  'Thaddeus Young16',
#  'Jerami Grant16',
#  'Jerian Grant16',
#  'Mason Plumlee16',
#  'Miles Plumlee16',
#  'Justin Anderson16',
#  'James Anderson16',
#  'Jrue Holiday16',
#  'Justin Holiday16',
#  'Aaron Wiggins16',
#  'Andrew Wiggins16',
#  'Bojan Bogdanovic16',
#  'Bogdan Bogdanovic16',
#  'Josh Jackson16',
#  'Justin Jackson16',
#  'Tyus Jones16',
#  'Tre Jones16',
#  'Terrence Jones16',
#  'Miles Bridges16',
#  'Mikal Bridges16',
#  'Cole Anthony16',
#  'Carmelo Anthony16',
#  'Lonzo Ball16',
#  'LaMelo Ball16',
# ...

# %%
df_name_clusters = pd.DataFrame()
player_name_before_after = pd.DataFrame()

last_name_list = []
for i, player_name in enumerate(players_clusters_df["Player"]):
    if player_name[:-2] == "Nene":
        df_name_clusters.loc[i, "name"] = player_name
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = player_name[:-2]
    elif player_name[:-2] == "Marcus Morris Sr.":
        df_name_clusters.loc[i, "name"] = "Marcus Morris"+player_name[-2:]
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = "Marcus Morris"
    elif player_name[:-2] == "Luc Mbah a Moute":
        df_name_clusters.loc[i, "name"] = "L. Mbah a Moute"+player_name[-2:]
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = "L. Mbah a Moute"
    elif len(player_name.split()) == 3:
        first_name, last_name, etc = player_name.split()[0], player_name.split()[1], player_name.split()[2]
        df_name_clusters.loc[i, "name"] = first_name[0]+". "+last_name+" "+etc
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = first_name[0]+". "+last_name+" "+etc[:-2]
    elif player_name in confusing_name_year_list:
        df_name_clusters.loc[i, "name"] = player_name
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = player_name[:-2]
    else:
        first_name, last_name = player_name.split()[0], player_name.split()[1]
        last_name_list.append(last_name)
        df_name_clusters.loc[i, "name"] = first_name[0]+". "+last_name
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names] 
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = first_name[0]+". "+last_name[:-2]

# %%
player_name_before_after.drop_duplicates(inplace=True)
player_name_before_after
# Out:
#                before          after
# 0        Aaron Brooks      A. Brooks
# 3       Aaron Holiday     A. Holiday
# 8       Aaron Nesmith     A. Nesmith
# 11         Al Horford     A. Horford
# 19      Aaron Wiggins  Aaron Wiggins
# ...               ...            ...
# 3036    Zach Randolph    Z. Randolph
# 3039    Zaza Pachulia    Z. Pachulia
# 3043       Zeke Nnaji       Z. Nnaji
# 3046  Ziaire Williams    Z. Williams
# 3048  Zion Williamson  Z. Williamson
#
# [711 rows x 2 columns]

# %%
with open('../pickle_files/lineups_dict2.pkl', 'rb') as f:
    lineups_dict = pickle.load(f)

# %%
df_name_clusters_dict = {}
for y in range(16, 24):
    df_name_clusters_dict[y] = df_name_clusters.query('name.str.endswith("'+str(y)+'")')

# %%
cluster_names = ["Mid-range Big",
                 "Traditional Center_A",
                 "Flore General",
                 "High-usage Guard",
                 "Versatile Role-player",
                 "Rim Plotecter",
                 "Traditional Center_B",
                 "Stretch Forward",
                 "3-point Shooting-guard"
                 ]

# %%
lineup_cluster_dict = {}
for y, lineups in lineups_dict.items():
    for n in range(1, 6):
        df = df_name_clusters.rename(columns={"name": 'PLAYER'+str(n),
                                              "Mid-range Big": "Mid-range Big"+str(n),
                                              "Traditional Center_A": "Traditional Center_A"+str(n),
                                              "Flore General": "Flore General"+str(n),
                                              "High-usage Guard": "High-usage Guard"+str(n),
                                              "Versatile Role-player": "Versatile Role-player"+str(n),
                                              "Rim Plotecter": "Rim Plotecter"+str(n),
                                              "Traditional Center_B": "Traditional Center_B"+str(n),
                                              "Stretch Forward": "Stretch Forward"+str(n),
                                              "3-point Shooting-guard": "3-point Shooting-guard"+str(n)
                                              })
        lineups = pd.merge(lineups, df, on="PLAYER"+str(n), how="left")
        
    for i in range(len(lineups)):
        lineup_sum = 0
        for cluster in cluster_names:
            cluster_sum = 0
            for n in range(1, 6):
                cluster_sum += lineups.loc[i, cluster+str(n)]
            lineups.loc[i, cluster] = cluster_sum
            lineup_sum += cluster_sum
        if 4.9 < lineup_sum < 5.1:
            continue
    lineups.dropna(inplace=True)
    lineup_cluster_dict[y] = lineups

# %%
lineups_df = pd.concat(lineup_cluster_dict.values())
lineups_df.reset_index(inplace=True, drop=True)
lineups_df
# Out:
#                                                 LINEUPS TEAM  GP_x  MIN_x  \
# 0     E. Ilyasova - M. Morris - R. Jackson - A. Drum...  DET    48    915
# 1     K. Korver - P. Millsap - A. Horford - J. Teagu...  ATL    70    892
# 2     K. Durant - R. Westbrook - S. Ibaka - A. Rober...  OKC    59    816
# 3     C. Anthony - J. Calderon - A. Afflalo - R. Lop...  NYK    50    735
# 4     A. Johnson - A. Bradley - I. Thomas - J. Sulli...  BOS    60    723
# ...                                                 ...  ...   ...    ...
# 2380  T. Hardaway Jr. - S. Dinwiddie - C. Wood - M. ...  DAL     9     51
# 2381  T. McConnell - M. Turner - B. Hield - A. Nesmi...  IND     6     51
# 2382  A. Burks - B. Bogdanovic - I. Stewart - J. Ive...  DET     6     50
# 2383  L. James - R. Westbrook - A. Davis - L. Walker...  LAL    15     50
# 2384  P. Siakam - F. VanVleet - O. Anunoby - G. Tren...  TOR    13     50
#
#       OFFRTG_x  DEFRTG_x  NETRTG_x  AST%_x  AST/TO_x  AST RATIO_x  ...  \
# ...

# %%
with open('../pickle_files/lineups_df2.pkl', 'rb') as f:
    lineups_df2 = pickle.load(f)

# %%
merged_df = pd.merge(lineups_df, lineups_df2, on=["LINEUPS", "GP_x", "MIN_x"], how="right")

# %%
kalman2020_lineup_data2 = merged_df[["LINEUPS", "TEAM_x", "OFFRTG_x"]+cluster_names].rename(columns={"TEAM_x": "TEAM", "OFFRTG_x": "OFFRTG"})
kalman2020_lineup_data2
# Out:
#                                                 LINEUPS TEAM      OFFRTG  \
# 0     E. Ilyasova - M. Morris - R. Jackson - A. Drum...  DET  105.200000
# 1     K. Korver - P. Millsap - A. Horford - J. Teagu...  ATL  104.300000
# 2     K. Durant - R. Westbrook - S. Ibaka - A. Rober...  OKC  114.300000
# 3     C. Anthony - J. Calderon - A. Afflalo - R. Lop...  NYK  103.600000
# 4     A. Johnson - A. Bradley - I. Thomas - J. Sulli...  BOS  106.400000
# ...                                                 ...  ...         ...
# 2265  T. Hardaway Jr. - S. Dinwiddie - C. Wood - M. ...  DAL  112.194000
# 2266  T. McConnell - M. Turner - B. Hield - A. Nesmi...  IND  113.817000
# 2267  A. Burks - B. Bogdanovic - I. Stewart - J. Ive...  DET  108.400000
# 2268  L. James - R. Westbrook - A. Davis - L. Walker...  LAL  115.416667
# 2269  P. Siakam - F. VanVleet - O. Anunoby - G. Tren...  TOR  117.666667
#
#       Mid-range Big  Traditional Center_A  Flore General  High-usage Guard  \
# ...

# %%
with open('../pickle_files/kalman2020_lineup_data2.pkl', 'wb') as f:
    pickle.dump(kalman2020_lineup_data2, f)

# %%
scaled_values_1 = scaler.fit_transform(kalman_features_1.drop("Player", axis=1))
scaled_df_1 = pd.DataFrame(scaled_values_1, columns=kalman_features_1.columns[1:])
scaled_df_1
# Out:
#         Height    FG%_2P    FG%_3P  %_FG_Ast'd_2P  %_FG_Ast'd_3P  \
# 0    -1.891843  0.275137  0.575786      -1.590791      -0.304652
# 1    -1.891843 -1.255954  0.676121      -1.976011      -0.130943
# 2    -1.891843 -0.781316  0.676121      -2.041904      -0.388511
# 3    -1.891843 -0.965047  0.461117      -2.224377      -0.496330
# 4    -1.891843 -1.056912  0.590120      -2.193965      -0.475365
# ...        ...       ...       ...            ...            ...
# 2460  1.258718 -0.566963 -2.097430       1.080405      -2.221437
# 2461  1.258718 -0.367921 -2.097430       0.766146      -2.221437
# 2462  1.258718  0.688531 -2.097430       1.399732      -2.221437
# 2463  1.258718  1.132547 -2.097430       1.470693      -2.221437
# 2464  1.258718 -0.658828 -2.097430       0.482300      -2.221437
#
#       Corner3P_%_FGA  Dunk_%_FGA  %_FGA_0-3  %_FGA_3-10  %_FGA_10-3P  ...  \
# 0          -0.286189   -0.759737  -0.517895   -0.213801    -0.137554  ...
# ...

# %%
gmm = GaussianMixture(n_components=9, random_state=6, covariance_type="tied")
gmm.fit(scaled_df_1)
labels = gmm.predict(scaled_df_1)
labels_df = pd.DataFrame(labels)
labeled_df = pd.concat([kalman_features_1['Player'], labels_df, scaled_df_1], axis=1)
labeled_df
# Out:
#                Player  0    Height    FG%_2P    FG%_3P  %_FG_Ast'd_2P  \
# 0      Aaron Brooks13  1 -1.891843  0.275137  0.575786      -1.590791
# 1      Aaron Brooks14  1 -1.891843 -1.255954  0.676121      -1.976011
# 2      Aaron Brooks15  1 -1.891843 -0.781316  0.676121      -2.041904
# 3      Aaron Brooks16  8 -1.891843 -0.965047  0.461117      -2.224377
# 4      Aaron Brooks17  1 -1.891843 -1.056912  0.590120      -2.193965
# ...               ... ..       ...       ...       ...            ...
# 2460  Zaza Pachulia15  6  1.258718 -0.566963 -2.097430       1.080405
# 2461  Zaza Pachulia16  6  1.258718 -0.367921 -2.097430       0.766146
# 2462  Zaza Pachulia17  6  1.258718  0.688531 -2.097430       1.399732
# 2463  Zaza Pachulia18  6  1.258718  1.132547 -2.097430       1.470693
# 2464  Zaza Pachulia19  6  1.258718 -0.658828 -2.097430       0.482300
#
#       %_FG_Ast'd_3P  Corner3P_%_FGA  Dunk_%_FGA  %_FGA_0-3  ...      AST%  \
# ...

# %%
cluster_names = ["Skilled Forwared",
                 "Flore General",
                 "Stretch Forward",
                 "Traditional Center_A",
                 "3-point Shoonting-guard",
                 "Traditional Center_B",
                 "Traditional_Center_C",
                 "Mid-range Big",
                 "High-usage Guard"
                 ]

# %%
membership_probability = gmm.predict_proba(scaled_df_1)
membership_probability
# Out:
# array([[4.10301116e-09, 9.93136462e-01, 2.17251206e-08, ...,
#         4.54715640e-37, 2.08625672e-11, 6.31625311e-03],
#        [8.26253318e-09, 9.95495879e-01, 6.97841193e-09, ...,
#         1.00977873e-41, 5.98846528e-11, 3.84090150e-03],
#        [5.52466309e-11, 6.37815293e-01, 9.45001084e-11, ...,
#         2.74817461e-39, 1.93318738e-13, 3.62143996e-01],
#        ...,
#        [2.72220974e-47, 3.50290821e-46, 5.87353017e-51, ...,
#         1.00000000e+00, 3.78780086e-43, 2.03093175e-37],
#        [2.39787778e-47, 3.66737808e-46, 1.02535107e-50, ...,
#         1.00000000e+00, 1.98410851e-43, 2.68279720e-37],
#        [5.19043506e-45, 5.00897488e-42, 6.11083474e-49, ...,
#         1.00000000e+00, 7.45887741e-41, 1.52752267e-33]])

# %%
players_clusters_df = pd.concat([kalman_features_1['Player'], 
                        pd.DataFrame(membership_probability, columns=cluster_names)],
                        axis=1)
players_clusters_df
# Out:
#                Player  Skilled Forwared  Flore General  Stretch Forward  \
# 0      Aaron Brooks13      4.103011e-09   9.931365e-01     2.172512e-08
# 1      Aaron Brooks14      8.262533e-09   9.954959e-01     6.978412e-09
# 2      Aaron Brooks15      5.524663e-11   6.378153e-01     9.450011e-11
# 3      Aaron Brooks16      3.926814e-12   2.087235e-01     5.631242e-12
# 4      Aaron Brooks17      3.287700e-11   7.565081e-01     5.558864e-11
# ...               ...               ...            ...              ...
# 2460  Zaza Pachulia15      1.899873e-45   2.512693e-43     9.109369e-49
# 2461  Zaza Pachulia16      2.992825e-46   4.941407e-45     5.656454e-50
# 2462  Zaza Pachulia17      2.722210e-47   3.502908e-46     5.873530e-51
# 2463  Zaza Pachulia18      2.397878e-47   3.667378e-46     1.025351e-50
# 2464  Zaza Pachulia19      5.190435e-45   5.008975e-42     6.110835e-49
#
#       Traditional Center_A  3-point Shoonting-guard  Traditional Center_B  \
# ...

# %%
confusing_name_list = ["JaMychal Green", "Jeff Green",
                        "Draymond Green", "Danny Green", 
                        "Stephen Curry", "Seth Curry", 
                        "Marcus Morris", "Markieff Morris",
                        "JR Smith", "Jason Smith", "Josh Smith",
                        "James Johnson", "Joe Johnson",
                        "Deron Williams", "Derrick Williams",
                        "Marvin Williams", "Mo Williams",
                        "Trae Young", "Thaddeus Young",
                        "Jerami Grant", "Jerian Grant"
                        ]
confusing_name_year_list = []
for y in range(13,20):
    for confusing_name in confusing_name_list:
        confusing_name_year_list.append(confusing_name+str(y))
confusing_name_year_list
# Out:
# ['JaMychal Green13',
#  'Jeff Green13',
#  'Draymond Green13',
#  'Danny Green13',
#  'Stephen Curry13',
#  'Seth Curry13',
#  'Marcus Morris13',
#  'Markieff Morris13',
#  'JR Smith13',
#  'Jason Smith13',
#  'Josh Smith13',
#  'James Johnson13',
#  'Joe Johnson13',
#  'Deron Williams13',
#  'Derrick Williams13',
#  'Marvin Williams13',
#  'Mo Williams13',
#  'Trae Young13',
#  'Thaddeus Young13',
#  'Jerami Grant13',
#  'Jerian Grant13',
#  'JaMychal Green14',
#  'Jeff Green14',
#  'Draymond Green14',
#  'Danny Green14',
#  'Stephen Curry14',
#  'Seth Curry14',
#  'Marcus Morris14',
#  'Markieff Morris14',
#  'JR Smith14',
#  'Jason Smith14',
#  'Josh Smith14',
#  'James Johnson14',
#  'Joe Johnson14',
#  'Deron Williams14',
#  'Derrick Williams14',
#  'Marvin Williams14',
#  'Mo Williams14',
#  'Trae Young14',
#  'Thaddeus Young14',
#  'Jerami Grant14',
#  'Jerian Grant14',
#  'JaMychal Green15',
#  'Jeff Green15',
#  'Draymond Green15',
#  'Danny Green15',
#  'Stephen Curry15',
# ...

# %%
df_name_clusters = pd.DataFrame()
player_name_before_after = pd.DataFrame()

last_name_list = []
for i, player_name in enumerate(players_clusters_df["Player"]):
    if player_name[:-2] == "Nene":
        df_name_clusters.loc[i, "name"] = player_name
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = player_name[:-2]
    elif player_name[:-2] == "Marcus Morris Sr.":
        df_name_clusters.loc[i, "name"] = "Marcus Morris"+player_name[-2:]
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = "Marcus Morris"
    elif player_name[:-2] == "Luc Mbah a Moute":
        df_name_clusters.loc[i, "name"] = "L. Mbah a Moute"+player_name[-2:]
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = "L. Mbah a Moute"
    elif len(player_name.split()) == 3:
        first_name, last_name, etc = player_name.split()[0], player_name.split()[1], player_name.split()[2]
        df_name_clusters.loc[i, "name"] = first_name[0]+". "+last_name+" "+etc
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = first_name[0]+". "+last_name+" "+etc[:-2]
    elif player_name in confusing_name_year_list:
        df_name_clusters.loc[i, "name"] = player_name
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names]
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = player_name[:-2]
    else:
        first_name, last_name = player_name.split()[0], player_name.split()[1]
        last_name_list.append(last_name)
        df_name_clusters.loc[i, "name"] = first_name[0]+". "+last_name
        df_name_clusters.loc[i, cluster_names] = players_clusters_df.loc[i, cluster_names] 
        player_name_before_after.loc[i, "before"] = player_name[:-2]
        player_name_before_after.loc[i, "after"] = first_name[0]+". "+last_name[:-2]

# %%
with open('../pickle_files/shot_data.pkl', 'rb') as f:
    shot_count_by_player = pickle.load(f)
    shot_features_df = pickle.load(f)
    meta_features_df = pickle.load(f)
    pca_result = pickle.load(f)
    player_30 = pickle.load(f)
    pca_result_30 = pickle.load(f)

# %%
player_30 = pd.DataFrame(player_30, columns=["before"])
player_30
# Out:
#               before
# 0         Kyle Lowry
# 1      Nicolas Batum
# 2      DeMar DeRozan
# 3        PJ Hairston
# 4       Kemba Walker
# ..               ...
# 320   Derrick Favors
# 321       Alec Burks
# 322  Lamar Patterson
# 323     Al Jefferson
# 324     Eric Bledsoe
#
# [325 rows x 1 columns]

# %%
player_df_before_after = pd.merge(player_30, player_name_before_after, on="before", how="left")

# %%
with open('../pickle_files/lineups_dict1.pkl', 'rb') as f:
    lineups_dict = pickle.load(f)

# %%
for y, lineups in lineups_dict.items():
    for n in range(1, 6):
        lineups["PLAYER"+str(n)] = lineups["PLAYER"+str(n)]+str(y)

# %%
lineup_cluster_dict = {}
for y, lineups in lineups_dict.items():
    for n in range(1, 6):
        df = df_name_clusters.rename(columns={"name": 'PLAYER'+str(n),
                                              "Skilled Forwared": "Skilled Forwared"+str(n),
                                              "Flore General": "Flore General"+str(n),
                                              "Stretch Forward": "Stretch Forward"+str(n),
                                              "Traditional Center_A": "Traditional Center_A"+str(n),
                                              "3-point Shoonting-guard": "3-point Shoonting-guard"+str(n),
                                              "Traditional Center_B": "Traditional Center_B"+str(n),
                                              "Traditional_Center_C": "Traditional_Center_C"+str(n),
                                              "Mid-range Big": "Mid-range Big"+str(n),
                                              "High-usage Guard": "High-usage Guard"+str(n)
                                              })
        lineups = pd.merge(lineups, df, on="PLAYER"+str(n), how="left")
        
    for i in range(len(lineups)):
        lineup_sum = 0
        for cluster in cluster_names:
            cluster_sum = 0
            for n in range(1, 6):
                cluster_sum += lineups.loc[i, cluster+str(n)]
            lineups.loc[i, cluster] = cluster_sum
            lineup_sum += cluster_sum
        if lineup_sum < 4.9 and lineup_sum > 5.1:
            print(lineups.iloc[i, :])
            
    #print(lineups[lineups.isnull().any(axis=1)])
    lineups.dropna(inplace=True)
    lineup_cluster_dict[y] = lineups

# %%
lineups_df = pd.concat(lineup_cluster_dict.values())
lineups_df.reset_index(inplace=True, drop=True)
lineups_df
# Out:
#                                                 LINEUPS TEAM  GP_x  MIN_x  \
# 0     D. West - R. Hibbert - G. Hill - P. George - L...  IND    64   1218
# 1     L. Aldridge - J. Hickson - N. Batum - W. Matth...  POR    60   1143
# 2     A. Iguodala - D. Gallinari - K. Koufos - T. La...  DEN    62    797
# 3     Z. Randolph - T. Allen - R. Gay - M. Conley - ...  MEM    35    631
# 4     O. Asik - J. Harden - P. Patterson - J. Lin - ...  HOU    37    567
# ...                                                 ...  ...   ...    ...
# 2022  G. Dragic - H. Whiteside - R. McGruder - J. Wi...  MIA     6     50
# 2023  J. Green - J. Wall - M. Morris - B. Beal - O. ...  WAS     9     50
# 2024  J. Holiday - D. Miller - J. Okafor - F. Jackso...  NOP     7     50
# 2025  J. Holiday - D. Miller - J. Okafor - F. Jackso...  NOP     7     50
# 2026  T. Ross - J. Simmons - J. Grant - J. Martin - ...  ORL     8     50
#
#       OFFRTG_x  DEFRTG_x  NETRTG_x  AST%_x  AST/TO_x  AST RATIO_x  ...  \
# ...

# %%
with open('../pickle_files/lineups_df1.pkl', 'rb') as f:
    lineups_df1 = pickle.load(f)

# %%
lineups_df.drop_duplicates(subset=["LINEUPS", "MIN_x", "DEFRTG_x"], inplace=True)

# %%
merged_df = pd.merge(lineups_df, lineups_df1, on=["LINEUPS", "TEAM", "GP_x", "MIN_x", "OFFRTG"], how="right")

# %%
kalman2020_lineup_data1 = merged_df[["LINEUPS", "TEAM", "OFFRTG"]+cluster_names]
kalman2020_lineup_data1
# Out:
#                                                LINEUPS TEAM      OFFRTG  \
# 0    D. West - R. Hibbert - G. Hill - P. George - L...  IND  109.000000
# 1    L. Aldridge - J. Hickson - N. Batum - W. Matth...  POR  104.800000
# 2    A. Iguodala - D. Gallinari - K. Koufos - T. La...  DEN  108.000000
# 3    Z. Randolph - T. Allen - R. Gay - M. Conley - ...  MEM  102.900000
# 4    Z. Randolph - T. Prince - T. Allen - M. Conley...  MEM  102.200000
# ..                                                 ...  ...         ...
# 990  A. Horford - G. Hayward - K. Irving - M. Morri...  BOS  110.310667
# 991  J. Wall - M. Morris - B. Beal - O. Porter Jr. ...  WAS  109.511000
# 992  J. Dudley - D. Carroll - E. Davis - S. Napier ...  BKN  108.254000
# 993  P. Tucker - E. Gordon - J. Harden - A. Rivers ...  HOU  111.704000
# 994  J. Green - J. Wall - M. Morris - B. Beal - O. ...  WAS  112.833333
#
#      Skilled Forwared  Flore General  Stretch Forward  Traditional Center_A  \
# ...

# %%
with open('../pickle_files/kalman2020_lineup_data1.pkl', 'wb') as f:
    pickle.dump(kalman2020_lineup_data1, f)
