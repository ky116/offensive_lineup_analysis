# %%
from basketball_reference_web_scraper import client
import pickle
import pandas as pd
from decimal import Decimal, ROUND_HALF_UP
import seaborn as sns
import matplotlib.pyplot as plt

# %%
shot_efficiency_stats_df = pd.DataFrame(columns=["name", "attempted_field_goals", "eFG%", "TS%"])

# %%
stats_2016 = client.players_season_totals(season_end_year=2016)
advanced_stats_2016 = client.players_advanced_season_totals(season_end_year=2016)

# %%
stats_2016
# Out:
# [{'slug': 'acyqu01',
#   'name': 'Quincy Acy',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 25,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 59,
#   'games_started': 29,
#   'minutes_played': 876,
#   'made_field_goals': 119,
#   'attempted_field_goals': 214,
#   'made_three_point_field_goals': 19,
#   'attempted_three_point_field_goals': 49,
#   'made_free_throws': 50,
#   'attempted_free_throws': 68,
#   'offensive_rebounds': 65,
#   'defensive_rebounds': 123,
#   'assists': 27,
#   'steals': 29,
#   'blocks': 24,
#   'turnovers': 27,
#   'personal_fouls': 103,
#   'points': 307},
#  {'slug': 'adamsjo01',
#   'name': 'Jordan Adams',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 21,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 2,
#   'games_started': 0,
#   'minutes_played': 15,
#   'made_field_goals': 2,
#   'attempted_field_goals': 6,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 3,
#   'attempted_free_throws': 5,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 2,
#   'assists': 3,
#   'steals': 3,
#   'blocks': 0,
#   'turnovers': 2,
#   'personal_fouls': 2,
#   'points': 7},
#  {'slug': 'adamsst01',
#   'name': 'Steven Adams',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 22,
#   'team': <Team.OKLAHOMA_CITY_THUNDER: 'OKLAHOMA CITY THUNDER'>,
#   'games_played': 80,
#   'games_started': 80,
#   'minutes_played': 2014,
#   'made_field_goals': 261,
#   'attempted_field_goals': 426,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 114,
#   'attempted_free_throws': 196,
#   'offensive_rebounds': 219,
#   'defensive_rebounds': 314,
#   'assists': 62,
#   'steals': 42,
#   'blocks': 89,
#   'turnovers': 84,
#   'personal_fouls': 223,
#   'points': 636},
#  {'slug': 'afflaar01',
#   'name': 'Arron Afflalo',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 30,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 71,
#   'games_started': 57,
#   'minutes_played': 2371,
#   'made_field_goals': 354,
#   'attempted_field_goals': 799,
#   'made_three_point_field_goals': 91,
#   'attempted_three_point_field_goals': 238,
#   'made_free_throws': 110,
#   'attempted_free_throws': 131,
#   'offensive_rebounds': 23,
#   'defensive_rebounds': 243,
#   'assists': 144,
#   'steals': 25,
#   'blocks': 10,
#   'turnovers': 82,
#   'personal_fouls': 142,
#   'points': 909},
#  {'slug': 'ajincal01',
#   'name': 'Alexis Ajinça',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 27,
#   'team': <Team.NEW_ORLEANS_PELICANS: 'NEW ORLEANS PELICANS'>,
#   'games_played': 59,
#   'games_started': 17,
#   'minutes_played': 861,
#   'made_field_goals': 150,
#   'attempted_field_goals': 315,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 52,
#   'attempted_free_throws': 62,
#   'offensive_rebounds': 75,
#   'defensive_rebounds': 194,
#   'assists': 31,
#   'steals': 19,
#   'blocks': 36,
#   'turnovers': 54,
#   'personal_fouls': 134,
#   'points': 352},
#  {'slug': 'aldrico01',
#   'name': 'Cole Aldrich',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 27,
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'games_played': 60,
#   'games_started': 5,
#   'minutes_played': 800,
#   'made_field_goals': 134,
#   'attempted_field_goals': 225,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 60,
#   'attempted_free_throws': 84,
#   'offensive_rebounds': 86,
#   'defensive_rebounds': 202,
#   'assists': 50,
#   'steals': 47,
#   'blocks': 68,
#   'turnovers': 64,
#   'personal_fouls': 139,
#   'points': 328},
#  {'slug': 'aldrila01',
#   'name': 'LaMarcus Aldridge',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 30,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 74,
#   'games_started': 74,
#   'minutes_played': 2261,
#   'made_field_goals': 536,
#   'attempted_field_goals': 1045,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 16,
#   'made_free_throws': 259,
#   'attempted_free_throws': 302,
#   'offensive_rebounds': 176,
#   'defensive_rebounds': 456,
#   'assists': 110,
#   'steals': 38,
#   'blocks': 81,
#   'turnovers': 99,
#   'personal_fouls': 151,
#   'points': 1331},
#  {'slug': 'alexacl01',
#   'name': 'Cliff Alexander',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 20,
#   'team': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'games_played': 8,
#   'games_started': 0,
#   'minutes_played': 36,
#   'made_field_goals': 5,
#   'attempted_field_goals': 10,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 2,
#   'defensive_rebounds': 4,
#   'assists': 0,
#   'steals': 1,
#   'blocks': 2,
#   'turnovers': 1,
#   'personal_fouls': 1,
#   'points': 10},
#  {'slug': 'allenla01',
#   'name': 'Lavoy Allen',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 26,
#   'team': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'games_played': 79,
#   'games_started': 28,
#   'minutes_played': 1599,
#   'made_field_goals': 191,
#   'attempted_field_goals': 370,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 46,
#   'attempted_free_throws': 73,
#   'offensive_rebounds': 162,
#   'defensive_rebounds': 262,
#   'assists': 76,
#   'steals': 26,
#   'blocks': 42,
#   'turnovers': 69,
#   'personal_fouls': 147,
#   'points': 428},
#  {'slug': 'allento01',
#   'name': 'Tony Allen',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 34,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 64,
#   'games_started': 57,
#   'minutes_played': 1620,
#   'made_field_goals': 215,
#   'attempted_field_goals': 469,
#   'made_three_point_field_goals': 15,
#   'attempted_three_point_field_goals': 42,
#   'made_free_throws': 90,
#   'attempted_free_throws': 138,
#   'offensive_rebounds': 104,
#   'defensive_rebounds': 192,
#   'assists': 70,
#   'steals': 110,
#   'blocks': 18,
#   'turnovers': 78,
#   'personal_fouls': 175,
#   'points': 535},
#  {'slug': 'aminual01',
#   'name': 'Al-Farouq Aminu',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 25,
#   'team': <Team.PORTLAND_TRAIL_BLAZERS: 'PORTLAND TRAIL BLAZERS'>,
#   'games_played': 82,
#   'games_started': 82,
#   'minutes_played': 2341,
#   'made_field_goals': 299,
#   'attempted_field_goals': 719,
#   'made_three_point_field_goals': 126,
#   'attempted_three_point_field_goals': 349,
#   'made_free_throws': 115,
#   'attempted_free_throws': 156,
#   'offensive_rebounds': 98,
#   'defensive_rebounds': 401,
#   'assists': 138,
#   'steals': 72,
#   'blocks': 53,
#   'turnovers': 120,
#   'personal_fouls': 171,
#   'points': 839},
#  {'slug': 'amundlo01',
#   'name': 'Lou Amundson',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 33,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 29,
#   'games_started': 0,
#   'minutes_played': 204,
#   'made_field_goals': 19,
#   'attempted_field_goals': 53,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 14,
#   'attempted_free_throws': 27,
#   'offensive_rebounds': 23,
#   'defensive_rebounds': 26,
#   'assists': 12,
#   'steals': 6,
#   'blocks': 7,
#   'turnovers': 15,
#   'personal_fouls': 44,
#   'points': 52},
#  {'slug': 'anderch01',
#   'name': 'Chris Andersen',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 37,
#   'team': <Team.MIAMI_HEAT: 'MIAMI HEAT'>,
#   'games_played': 7,
#   'games_started': 1,
#   'minutes_played': 36,
#   'made_field_goals': 4,
#   'attempted_field_goals': 10,
#   'made_three_point_field_goals': 2,
#   'attempted_three_point_field_goals': 5,
#   'made_free_throws': 3,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 6,
#   'assists': 3,
#   'steals': 1,
#   'blocks': 3,
#   'turnovers': 2,
#   'personal_fouls': 4,
#   'points': 13},
#  {'slug': 'anderch01',
#   'name': 'Chris Andersen',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 37,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 20,
#   'games_started': 14,
#   'minutes_played': 366,
#   'made_field_goals': 34,
#   'attempted_field_goals': 62,
#   'made_three_point_field_goals': 2,
#   'attempted_three_point_field_goals': 9,
#   'made_free_throws': 22,
#   'attempted_free_throws': 32,
#   'offensive_rebounds': 33,
#   'defensive_rebounds': 56,
#   'assists': 9,
#   'steals': 14,
#   'blocks': 10,
#   'turnovers': 7,
#   'personal_fouls': 25,
#   'points': 92},
#  {'slug': 'anderal01',
#   'name': 'Alan Anderson',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 33,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 13,
#   'games_started': 0,
#   'minutes_played': 192,
#   'made_field_goals': 21,
#   'attempted_field_goals': 59,
#   'made_three_point_field_goals': 12,
#   'attempted_three_point_field_goals': 37,
#   'made_free_throws': 11,
#   'attempted_free_throws': 15,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 26,
#   'assists': 14,
#   'steals': 4,
#   'blocks': 1,
#   'turnovers': 2,
#   'personal_fouls': 25,
#   'points': 65},
#  {'slug': 'anderja01',
#   'name': 'James Anderson',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 26,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 51,
#   'games_started': 15,
#   'minutes_played': 721,
#   'made_field_goals': 67,
#   'attempted_field_goals': 178,
#   'made_three_point_field_goals': 23,
#   'attempted_three_point_field_goals': 86,
#   'made_free_throws': 22,
#   'attempted_free_throws': 29,
#   'offensive_rebounds': 13,
#   'defensive_rebounds': 73,
#   'assists': 41,
#   'steals': 21,
#   'blocks': 14,
#   'turnovers': 42,
#   'personal_fouls': 54,
#   'points': 179},
#  {'slug': 'anderju01',
#   'name': 'Justin Anderson',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 22,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 55,
#   'games_started': 9,
#   'minutes_played': 647,
#   'made_field_goals': 71,
#   'attempted_field_goals': 175,
#   'made_three_point_field_goals': 22,
#   'attempted_three_point_field_goals': 83,
#   'made_free_throws': 44,
#   'attempted_free_throws': 55,
#   'offensive_rebounds': 18,
#   'defensive_rebounds': 114,
#   'assists': 29,
#   'steals': 19,
#   'blocks': 25,
#   'turnovers': 24,
#   'personal_fouls': 45,
#   'points': 208},
#  {'slug': 'anderky01',
#   'name': 'Kyle Anderson',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 22,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 78,
#   'games_started': 11,
#   'minutes_played': 1245,
#   'made_field_goals': 138,
#   'attempted_field_goals': 295,
#   'made_three_point_field_goals': 12,
#   'attempted_three_point_field_goals': 37,
#   'made_free_throws': 62,
#   'attempted_free_throws': 83,
#   'offensive_rebounds': 25,
#   'defensive_rebounds': 219,
#   'assists': 123,
#   'steals': 60,
#   'blocks': 29,
#   'turnovers': 59,
#   'personal_fouls': 97,
#   'points': 350},
#  {'slug': 'anderry01',
#   'name': 'Ryan Anderson',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 27,
#   'team': <Team.NEW_ORLEANS_PELICANS: 'NEW ORLEANS PELICANS'>,
#   'games_played': 66,
#   'games_started': 7,
#   'minutes_played': 2008,
#   'made_field_goals': 397,
#   'attempted_field_goals': 929,
#   'made_three_point_field_goals': 131,
#   'attempted_three_point_field_goals': 358,
#   'made_free_throws': 199,
#   'attempted_free_throws': 228,
#   'offensive_rebounds': 131,
#   'defensive_rebounds': 265,
#   'assists': 73,
#   'steals': 38,
#   'blocks': 25,
#   'turnovers': 90,
#   'personal_fouls': 109,
#   'points': 1124},
#  {'slug': 'antetgi01',
#   'name': 'Giannis Antetokounmpo',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 21,
#   'team': <Team.MILWAUKEE_BUCKS: 'MILWAUKEE BUCKS'>,
#   'games_played': 80,
#   'games_started': 79,
#   'minutes_played': 2823,
#   'made_field_goals': 513,
#   'attempted_field_goals': 1013,
#   'made_three_point_field_goals': 28,
#   'attempted_three_point_field_goals': 109,
#   'made_free_throws': 296,
#   'attempted_free_throws': 409,
#   'offensive_rebounds': 113,
#   'defensive_rebounds': 499,
#   'assists': 345,
#   'steals': 94,
#   'blocks': 113,
#   'turnovers': 208,
#   'personal_fouls': 258,
#   'points': 1350},
#  {'slug': 'antetth01',
#   'name': 'Thanasis Antetokounmpo',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 23,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 2,
#   'games_started': 0,
#   'minutes_played': 6,
#   'made_field_goals': 3,
#   'attempted_field_goals': 4,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 0,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 0,
#   'personal_fouls': 2,
#   'points': 6},
#  {'slug': 'anthoca01',
#   'name': 'Carmelo Anthony',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 31,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 72,
#   'games_started': 72,
#   'minutes_played': 2530,
#   'made_field_goals': 567,
#   'attempted_field_goals': 1307,
#   'made_three_point_field_goals': 105,
#   'attempted_three_point_field_goals': 310,
#   'made_free_throws': 334,
#   'attempted_free_throws': 403,
#   'offensive_rebounds': 98,
#   'defensive_rebounds': 458,
#   'assists': 299,
#   'steals': 62,
#   'blocks': 38,
#   'turnovers': 176,
#   'personal_fouls': 180,
#   'points': 1573},
#  {'slug': 'anthojo01',
#   'name': 'Joel Anthony',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 33,
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'games_played': 19,
#   'games_started': 0,
#   'minutes_played': 96,
#   'made_field_goals': 6,
#   'attempted_field_goals': 10,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 6,
#   'attempted_free_throws': 8,
#   'offensive_rebounds': 8,
#   'defensive_rebounds': 13,
#   'assists': 1,
#   'steals': 2,
#   'blocks': 12,
#   'turnovers': 2,
#   'personal_fouls': 15,
#   'points': 18},
#  {'slug': 'applike01',
#   'name': 'Keith Appling',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 23,
#   'team': <Team.ORLANDO_MAGIC: 'ORLANDO MAGIC'>,
#   'games_played': 5,
#   'games_started': 0,
#   'minutes_played': 27,
#   'made_field_goals': 2,
#   'attempted_field_goals': 8,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 3,
#   'made_free_throws': 2,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 1,
#   'assists': 1,
#   'steals': 1,
#   'blocks': 0,
#   'turnovers': 3,
#   'personal_fouls': 5,
#   'points': 6},
#  {'slug': 'arizatr01',
#   'name': 'Trevor Ariza',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 30,
#   'team': <Team.HOUSTON_ROCKETS: 'HOUSTON ROCKETS'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2859,
#   'made_field_goals': 357,
#   'attempted_field_goals': 859,
#   'made_three_point_field_goals': 185,
#   'attempted_three_point_field_goals': 499,
#   'made_free_throws': 126,
#   'attempted_free_throws': 161,
#   'offensive_rebounds': 67,
#   'defensive_rebounds': 299,
#   'assists': 188,
#   'steals': 160,
#   'blocks': 26,
#   'turnovers': 113,
#   'personal_fouls': 177,
#   'points': 1025},
#  {'slug': 'arthuda01',
#   'name': 'Darrell Arthur',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 27,
#   'team': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'games_played': 70,
#   'games_started': 16,
#   'minutes_played': 1516,
#   'made_field_goals': 221,
#   'attempted_field_goals': 489,
#   'made_three_point_field_goals': 45,
#   'attempted_three_point_field_goals': 117,
#   'made_free_throws': 40,
#   'attempted_free_throws': 53,
#   'offensive_rebounds': 86,
#   'defensive_rebounds': 207,
#   'assists': 96,
#   'steals': 53,
#   'blocks': 48,
#   'turnovers': 66,
#   'personal_fouls': 185,
#   'points': 527},
#  {'slug': 'asikom01',
#   'name': 'Ömer Aşık',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 29,
#   'team': <Team.NEW_ORLEANS_PELICANS: 'NEW ORLEANS PELICANS'>,
#   'games_played': 68,
#   'games_started': 64,
#   'minutes_played': 1178,
#   'made_field_goals': 104,
#   'attempted_field_goals': 195,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 61,
#   'attempted_free_throws': 112,
#   'offensive_rebounds': 120,
#   'defensive_rebounds': 294,
#   'assists': 26,
#   'steals': 21,
#   'blocks': 23,
#   'turnovers': 60,
#   'personal_fouls': 124,
#   'points': 269},
#  {'slug': 'augusdj01',
#   'name': 'D.J. Augustin',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 28,
#   'team': <Team.OKLAHOMA_CITY_THUNDER: 'OKLAHOMA CITY THUNDER'>,
#   'games_played': 34,
#   'games_started': 0,
#   'minutes_played': 519,
#   'made_field_goals': 46,
#   'attempted_field_goals': 121,
#   'made_three_point_field_goals': 24,
#   'attempted_three_point_field_goals': 61,
#   'made_free_throws': 26,
#   'attempted_free_throws': 34,
#   'offensive_rebounds': 5,
#   'defensive_rebounds': 38,
#   'assists': 66,
#   'steals': 13,
#   'blocks': 2,
#   'turnovers': 30,
#   'personal_fouls': 41,
#   'points': 142},
#  {'slug': 'augusdj01',
#   'name': 'D.J. Augustin',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 28,
#   'team': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'games_played': 28,
#   'games_started': 0,
#   'minutes_played': 659,
#   'made_field_goals': 102,
#   'attempted_field_goals': 229,
#   'made_three_point_field_goals': 44,
#   'attempted_three_point_field_goals': 107,
#   'made_free_throws': 77,
#   'attempted_free_throws': 94,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 49,
#   'assists': 132,
#   'steals': 25,
#   'blocks': 2,
#   'turnovers': 54,
#   'personal_fouls': 44,
#   'points': 325},
#  {'slug': 'pendeje02',
#   'name': 'Jeff Ayres',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 28,
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'games_played': 17,
#   'games_started': 0,
#   'minutes_played': 107,
#   'made_field_goals': 12,
#   'attempted_field_goals': 23,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 6,
#   'attempted_free_throws': 6,
#   'offensive_rebounds': 4,
#   'defensive_rebounds': 18,
#   'assists': 5,
#   'steals': 0,
#   'blocks': 3,
#   'turnovers': 6,
#   'personal_fouls': 18,
#   'points': 30},
#  {'slug': 'babbilu01',
#   'name': 'Luke Babbitt',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 26,
#   'team': <Team.NEW_ORLEANS_PELICANS: 'NEW ORLEANS PELICANS'>,
#   'games_played': 47,
#   'games_started': 13,
#   'minutes_played': 845,
#   'made_field_goals': 122,
#   'attempted_field_goals': 289,
#   'made_three_point_field_goals': 44,
#   'attempted_three_point_field_goals': 109,
#   'made_free_throws': 39,
#   'attempted_free_throws': 50,
#   'offensive_rebounds': 25,
#   'defensive_rebounds': 123,
#   'assists': 53,
#   'steals': 11,
#   'blocks': 7,
#   'turnovers': 23,
#   'personal_fouls': 90,
#   'points': 327},
#  {'slug': 'bairsca01',
#   'name': 'Cameron Bairstow',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 25,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 18,
#   'games_started': 2,
#   'minutes_played': 103,
#   'made_field_goals': 13,
#   'attempted_field_goals': 40,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 5,
#   'made_free_throws': 7,
#   'attempted_free_throws': 8,
#   'offensive_rebounds': 4,
#   'defensive_rebounds': 24,
#   'assists': 6,
#   'steals': 2,
#   'blocks': 3,
#   'turnovers': 4,
#   'personal_fouls': 19,
#   'points': 34},
#  {'slug': 'barbole01',
#   'name': 'Leandro Barbosa',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 33,
#   'team': <Team.GOLDEN_STATE_WARRIORS: 'GOLDEN STATE WARRIORS'>,
#   'games_played': 68,
#   'games_started': 0,
#   'minutes_played': 1079,
#   'made_field_goals': 171,
#   'attempted_field_goals': 370,
#   'made_three_point_field_goals': 39,
#   'attempted_three_point_field_goals': 110,
#   'made_free_throws': 52,
#   'attempted_free_throws': 62,
#   'offensive_rebounds': 28,
#   'defensive_rebounds': 89,
#   'assists': 82,
#   'steals': 44,
#   'blocks': 10,
#   'turnovers': 53,
#   'personal_fouls': 107,
#   'points': 433},
#  {'slug': 'bareajo01',
#   'name': 'J.J. Barea',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 31,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 74,
#   'games_started': 16,
#   'minutes_played': 1667,
#   'made_field_goals': 317,
#   'attempted_field_goals': 711,
#   'made_three_point_field_goals': 100,
#   'attempted_three_point_field_goals': 260,
#   'made_free_throws': 74,
#   'attempted_free_throws': 96,
#   'offensive_rebounds': 26,
#   'defensive_rebounds': 126,
#   'assists': 302,
#   'steals': 26,
#   'blocks': 2,
#   'turnovers': 113,
#   'personal_fouls': 110,
#   'points': 808},
#  {'slug': 'bargnan01',
#   'name': 'Andrea Bargnani',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 30,
#   'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'games_played': 46,
#   'games_started': 0,
#   'minutes_played': 634,
#   'made_field_goals': 127,
#   'attempted_field_goals': 279,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 16,
#   'made_free_throws': 47,
#   'attempted_free_throws': 57,
#   'offensive_rebounds': 28,
#   'defensive_rebounds': 69,
#   'assists': 18,
#   'steals': 4,
#   'blocks': 9,
#   'turnovers': 26,
#   'personal_fouls': 61,
#   'points': 304},
#  {'slug': 'barneha02',
#   'name': 'Harrison Barnes',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 23,
#   'team': <Team.GOLDEN_STATE_WARRIORS: 'GOLDEN STATE WARRIORS'>,
#   'games_played': 66,
#   'games_started': 59,
#   'minutes_played': 2042,
#   'made_field_goals': 295,
#   'attempted_field_goals': 633,
#   'made_three_point_field_goals': 82,
#   'attempted_three_point_field_goals': 214,
#   'made_free_throws': 102,
#   'attempted_free_throws': 134,
#   'offensive_rebounds': 77,
#   'defensive_rebounds': 248,
#   'assists': 117,
#   'steals': 41,
#   'blocks': 10,
#   'turnovers': 57,
#   'personal_fouls': 136,
#   'points': 774},
#  {'slug': 'barnema02',
#   'name': 'Matt Barnes',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 35,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 76,
#   'games_started': 45,
#   'minutes_played': 2190,
#   'made_field_goals': 264,
#   'attempted_field_goals': 693,
#   'made_three_point_field_goals': 119,
#   'attempted_three_point_field_goals': 370,
#   'made_free_throws': 111,
#   'attempted_free_throws': 138,
#   'offensive_rebounds': 84,
#   'defensive_rebounds': 336,
#   'assists': 163,
#   'steals': 78,
#   'blocks': 57,
#   'turnovers': 121,
#   'personal_fouls': 234,
#   'points': 758},
#  {'slug': 'bartowi01',
#   'name': 'Will Barton',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 25,
#   'team': <Team.DENVER_NUGGETS: 'DENVER NUGGETS'>,
#   'games_played': 82,
#   'games_started': 1,
#   'minutes_played': 2353,
#   'made_field_goals': 425,
#   'attempted_field_goals': 983,
#   'made_three_point_field_goals': 112,
#   'attempted_three_point_field_goals': 325,
#   'made_free_throws': 216,
#   'attempted_free_throws': 268,
#   'offensive_rebounds': 59,
#   'defensive_rebounds': 417,
#   'assists': 203,
#   'steals': 71,
#   'blocks': 39,
#   'turnovers': 139,
#   'personal_fouls': 147,
#   'points': 1178},
#  {'slug': 'bassbr01',
#   'name': 'Brandon Bass',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 30,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 66,
#   'games_started': 0,
#   'minutes_played': 1342,
#   'made_field_goals': 174,
#   'attempted_field_goals': 317,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 125,
#   'attempted_free_throws': 148,
#   'offensive_rebounds': 104,
#   'defensive_rebounds': 181,
#   'assists': 74,
#   'steals': 33,
#   'blocks': 55,
#   'turnovers': 42,
#   'personal_fouls': 125,
#   'points': 473},
#  {'slug': 'batumni01',
#   'name': 'Nicolas Batum',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 27,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 70,
#   'games_started': 70,
#   'minutes_played': 2448,
#   'made_field_goals': 372,
#   'attempted_field_goals': 873,
#   'made_three_point_field_goals': 139,
#   'attempted_three_point_field_goals': 399,
#   'made_free_throws': 163,
#   'attempted_free_throws': 192,
#   'offensive_rebounds': 55,
#   'defensive_rebounds': 373,
#   'assists': 403,
#   'steals': 65,
#   'blocks': 43,
#   'turnovers': 205,
#   'personal_fouls': 114,
#   'points': 1046},
#  {'slug': 'bayleje01',
#   'name': 'Jerryd Bayless',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 27,
#   'team': <Team.MILWAUKEE_BUCKS: 'MILWAUKEE BUCKS'>,
#   'games_played': 52,
#   'games_started': 18,
#   'minutes_played': 1505,
#   'made_field_goals': 185,
#   'attempted_field_goals': 437,
#   'made_three_point_field_goals': 101,
#   'attempted_three_point_field_goals': 231,
#   'made_free_throws': 70,
#   'attempted_free_throws': 90,
#   'offensive_rebounds': 21,
#   'defensive_rebounds': 120,
#   'assists': 163,
#   'steals': 47,
#   'blocks': 11,
#   'turnovers': 73,
#   'personal_fouls': 111,
#   'points': 541},
#  {'slug': 'baynear01',
#   'name': 'Aron Baynes',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 29,
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'games_played': 81,
#   'games_started': 1,
#   'minutes_played': 1233,
#   'made_field_goals': 194,
#   'attempted_field_goals': 384,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 126,
#   'attempted_free_throws': 165,
#   'offensive_rebounds': 140,
#   'defensive_rebounds': 244,
#   'assists': 51,
#   'steals': 21,
#   'blocks': 52,
#   'turnovers': 67,
#   'personal_fouls': 151,
#   'points': 514},
#  {'slug': 'bazemke01',
#   'name': 'Kent Bazemore',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 26,
#   'team': <Team.ATLANTA_HAWKS: 'ATLANTA HAWKS'>,
#   'games_played': 75,
#   'games_started': 68,
#   'minutes_played': 2083,
#   'made_field_goals': 320,
#   'attempted_field_goals': 725,
#   'made_three_point_field_goals': 109,
#   'attempted_three_point_field_goals': 305,
#   'made_free_throws': 123,
#   'attempted_free_throws': 151,
#   'offensive_rebounds': 28,
#   'defensive_rebounds': 351,
#   'assists': 171,
#   'steals': 98,
#   'blocks': 38,
#   'turnovers': 138,
#   'personal_fouls': 176,
#   'points': 872},
#  {'slug': 'bealbr01',
#   'name': 'Bradley Beal',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 22,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 55,
#   'games_started': 35,
#   'minutes_played': 1708,
#   'made_field_goals': 359,
#   'attempted_field_goals': 799,
#   'made_three_point_field_goals': 105,
#   'attempted_three_point_field_goals': 271,
#   'made_free_throws': 135,
#   'attempted_free_throws': 176,
#   'offensive_rebounds': 41,
#   'defensive_rebounds': 147,
#   'assists': 162,
#   'steals': 54,
#   'blocks': 11,
#   'turnovers': 112,
#   'personal_fouls': 117,
#   'points': 958},
#  {'slug': 'beaslmi01',
#   'name': 'Michael Beasley',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 27,
#   'team': <Team.HOUSTON_ROCKETS: 'HOUSTON ROCKETS'>,
#   'games_played': 20,
#   'games_started': 0,
#   'minutes_played': 363,
#   'made_field_goals': 107,
#   'attempted_field_goals': 205,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 9,
#   'made_free_throws': 38,
#   'attempted_free_throws': 49,
#   'offensive_rebounds': 29,
#   'defensive_rebounds': 69,
#   'assists': 16,
#   'steals': 11,
#   'blocks': 9,
#   'turnovers': 24,
#   'personal_fouls': 39,
#   'points': 255},
#  {'slug': 'belinma01',
#   'name': 'Marco Belinelli',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 29,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 68,
#   'games_started': 7,
#   'minutes_played': 1672,
#   'made_field_goals': 245,
#   'attempted_field_goals': 635,
#   'made_three_point_field_goals': 91,
#   'attempted_three_point_field_goals': 297,
#   'made_free_throws': 115,
#   'attempted_free_throws': 138,
#   'offensive_rebounds': 10,
#   'defensive_rebounds': 107,
#   'assists': 127,
#   'steals': 37,
#   'blocks': 2,
#   'turnovers': 80,
#   'personal_fouls': 91,
#   'points': 696},
#  {'slug': 'bennean01',
#   'name': 'Anthony Bennett',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 22,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 19,
#   'games_started': 0,
#   'minutes_played': 84,
#   'made_field_goals': 8,
#   'attempted_field_goals': 27,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 14,
#   'made_free_throws': 9,
#   'attempted_free_throws': 10,
#   'offensive_rebounds': 6,
#   'defensive_rebounds': 17,
#   'assists': 0,
#   'steals': 5,
#   'blocks': 0,
#   'turnovers': 4,
#   'personal_fouls': 8,
#   'points': 28},
#  {'slug': 'beverpa01',
#   'name': 'Patrick Beverley',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 27,
#   'team': <Team.HOUSTON_ROCKETS: 'HOUSTON ROCKETS'>,
#   'games_played': 71,
#   'games_started': 63,
#   'minutes_played': 2041,
#   'made_field_goals': 258,
#   'attempted_field_goals': 594,
#   'made_three_point_field_goals': 124,
#   'attempted_three_point_field_goals': 310,
#   'made_free_throws': 60,
#   'attempted_free_throws': 88,
#   'offensive_rebounds': 73,
#   'defensive_rebounds': 177,
#   'assists': 239,
#   'steals': 94,
#   'blocks': 26,
#   'turnovers': 91,
#   'personal_fouls': 234,
#   'points': 700},
#  {'slug': 'biyombi01',
#   'name': 'Bismack Biyombo',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 23,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 82,
#   'games_started': 22,
#   'minutes_played': 1808,
#   'made_field_goals': 156,
#   'attempted_field_goals': 288,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 142,
#   'attempted_free_throws': 226,
#   'offensive_rebounds': 182,
#   'defensive_rebounds': 473,
#   'assists': 29,
#   'steals': 19,
#   'blocks': 133,
#   'turnovers': 71,
#   'personal_fouls': 225,
#   'points': 454},
#  {'slug': 'bjeline01',
#   'name': 'Nemanja Bjelica',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 27,
#   'team': <Team.MINNESOTA_TIMBERWOLVES: 'MINNESOTA TIMBERWOLVES'>,
#   'games_played': 60,
#   'games_started': 0,
#   'minutes_played': 1075,
#   'made_field_goals': 110,
#   'attempted_field_goals': 235,
#   'made_three_point_field_goals': 48,
#   'attempted_three_point_field_goals': 125,
#   'made_free_throws': 40,
#   'attempted_free_throws': 55,
#   'offensive_rebounds': 49,
#   'defensive_rebounds': 161,
#   'assists': 83,
#   'steals': 26,
#   'blocks': 21,
#   'turnovers': 47,
#   'personal_fouls': 154,
#   'points': 308},
#  {'slug': 'blackta01',
#   'name': 'Tarik Black',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 24,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 39,
#   'games_started': 0,
#   'minutes_played': 496,
#   'made_field_goals': 57,
#   'attempted_field_goals': 104,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 19,
#   'attempted_free_throws': 45,
#   'offensive_rebounds': 44,
#   'defensive_rebounds': 113,
#   'assists': 16,
#   'steals': 14,
#   'blocks': 18,
#   'turnovers': 22,
#   'personal_fouls': 78,
#   'points': 133},
#  {'slug': 'blairde01',
#   'name': 'DeJuan Blair',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 26,
#   'team': <Team.WASHINGTON_WIZARDS: 'WASHINGTON WIZARDS'>,
#   'games_played': 29,
#   'games_started': 0,
#   'minutes_played': 218,
#   'made_field_goals': 28,
#   'attempted_field_goals': 68,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 5,
#   'attempted_free_throws': 13,
#   'offensive_rebounds': 20,
#   'defensive_rebounds': 37,
#   'assists': 11,
#   'steals': 8,
#   'blocks': 2,
#   'turnovers': 15,
#   'personal_fouls': 53,
#   'points': 61},
#  {'slug': 'blakest01',
#   'name': 'Steve Blake',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 35,
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'games_played': 58,
#   'games_started': 2,
#   'minutes_played': 986,
#   'made_field_goals': 93,
#   'attempted_field_goals': 240,
#   'made_three_point_field_goals': 52,
#   'attempted_three_point_field_goals': 151,
#   'made_free_throws': 16,
#   'attempted_free_throws': 20,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 80,
#   'assists': 200,
#   'steals': 24,
#   'blocks': 5,
#   'turnovers': 81,
#   'personal_fouls': 70,
#   'points': 254},
#  {'slug': 'bledser01',
#   'name': 'Eric Bledsoe',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 26,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 31,
#   'games_started': 31,
#   'minutes_played': 1059,
#   'made_field_goals': 223,
#   'attempted_field_goals': 492,
#   'made_three_point_field_goals': 48,
#   'attempted_three_point_field_goals': 129,
#   'made_free_throws': 138,
#   'attempted_free_throws': 172,
#   'offensive_rebounds': 18,
#   'defensive_rebounds': 107,
#   'assists': 190,
#   'steals': 63,
#   'blocks': 19,
#   'turnovers': 110,
#   'personal_fouls': 75,
#   'points': 632},
#  {'slug': 'bogdabo02',
#   'name': 'Bojan Bogdanović',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 26,
#   'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'games_played': 79,
#   'games_started': 39,
#   'minutes_played': 2115,
#   'made_field_goals': 324,
#   'attempted_field_goals': 749,
#   'made_three_point_field_goals': 129,
#   'attempted_three_point_field_goals': 338,
#   'made_free_throws': 110,
#   'attempted_free_throws': 132,
#   'offensive_rebounds': 36,
#   'defensive_rebounds': 219,
#   'assists': 99,
#   'steals': 29,
#   'blocks': 5,
#   'turnovers': 115,
#   'personal_fouls': 119,
#   'points': 887},
#  {'slug': 'bogutan01',
#   'name': 'Andrew Bogut',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 31,
#   'team': <Team.GOLDEN_STATE_WARRIORS: 'GOLDEN STATE WARRIORS'>,
#   'games_played': 70,
#   'games_started': 66,
#   'minutes_played': 1451,
#   'made_field_goals': 175,
#   'attempted_field_goals': 279,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 24,
#   'attempted_free_throws': 50,
#   'offensive_rebounds': 121,
#   'defensive_rebounds': 371,
#   'assists': 162,
#   'steals': 33,
#   'blocks': 114,
#   'turnovers': 83,
#   'personal_fouls': 221,
#   'points': 375},
#  {'slug': 'bonnema01',
#   'name': 'Matt Bonner',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 35,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 30,
#   'games_started': 2,
#   'minutes_played': 206,
#   'made_field_goals': 29,
#   'attempted_field_goals': 57,
#   'made_three_point_field_goals': 15,
#   'attempted_three_point_field_goals': 34,
#   'made_free_throws': 3,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 24,
#   'assists': 9,
#   'steals': 6,
#   'blocks': 1,
#   'turnovers': 3,
#   'personal_fouls': 16,
#   'points': 76},
#  {'slug': 'bookede01',
#   'name': 'Devin Booker',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 19,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 76,
#   'games_started': 51,
#   'minutes_played': 2108,
#   'made_field_goals': 367,
#   'attempted_field_goals': 867,
#   'made_three_point_field_goals': 99,
#   'attempted_three_point_field_goals': 289,
#   'made_free_throws': 215,
#   'attempted_free_throws': 256,
#   'offensive_rebounds': 27,
#   'defensive_rebounds': 160,
#   'assists': 200,
#   'steals': 44,
#   'blocks': 20,
#   'turnovers': 160,
#   'personal_fouls': 225,
#   'points': 1048},
#  {'slug': 'booketr01',
#   'name': 'Trevor Booker',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 28,
#   'team': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'games_played': 79,
#   'games_started': 2,
#   'minutes_played': 1632,
#   'made_field_goals': 190,
#   'attempted_field_goals': 388,
#   'made_three_point_field_goals': 12,
#   'attempted_three_point_field_goals': 41,
#   'made_free_throws': 71,
#   'attempted_free_throws': 106,
#   'offensive_rebounds': 166,
#   'defensive_rebounds': 286,
#   'assists': 84,
#   'steals': 59,
#   'blocks': 41,
#   'turnovers': 81,
#   'personal_fouls': 169,
#   'points': 463},
#  {'slug': 'boshch01',
#   'name': 'Chris Bosh',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 31,
#   'team': <Team.MIAMI_HEAT: 'MIAMI HEAT'>,
#   'games_played': 53,
#   'games_started': 53,
#   'minutes_played': 1778,
#   'made_field_goals': 358,
#   'attempted_field_goals': 767,
#   'made_three_point_field_goals': 81,
#   'attempted_three_point_field_goals': 222,
#   'made_free_throws': 213,
#   'attempted_free_throws': 268,
#   'offensive_rebounds': 48,
#   'defensive_rebounds': 342,
#   'assists': 128,
#   'steals': 36,
#   'blocks': 34,
#   'turnovers': 78,
#   'personal_fouls': 101,
#   'points': 1010},
#  {'slug': 'bradlav01',
#   'name': 'Avery Bradley',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 25,
#   'team': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#   'games_played': 76,
#   'games_started': 72,
#   'minutes_played': 2536,
#   'made_field_goals': 456,
#   'attempted_field_goals': 1019,
#   'made_three_point_field_goals': 147,
#   'attempted_three_point_field_goals': 407,
#   'made_free_throws': 96,
#   'attempted_free_throws': 123,
#   'offensive_rebounds': 48,
#   'defensive_rebounds': 172,
#   'assists': 158,
#   'steals': 117,
#   'blocks': 19,
#   'turnovers': 109,
#   'personal_fouls': 164,
#   'points': 1155},
#  {'slug': 'brandel01',
#   'name': 'Elton Brand',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 36,
#   'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'games_played': 17,
#   'games_started': 1,
#   'minutes_played': 225,
#   'made_field_goals': 31,
#   'attempted_field_goals': 72,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 1,
#   'made_free_throws': 8,
#   'attempted_free_throws': 9,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 54,
#   'assists': 18,
#   'steals': 9,
#   'blocks': 8,
#   'turnovers': 11,
#   'personal_fouls': 32,
#   'points': 70},
#  {'slug': 'breweco01',
#   'name': 'Corey Brewer',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 29,
#   'team': <Team.HOUSTON_ROCKETS: 'HOUSTON ROCKETS'>,
#   'games_played': 82,
#   'games_started': 12,
#   'minutes_played': 1669,
#   'made_field_goals': 212,
#   'attempted_field_goals': 552,
#   'made_three_point_field_goals': 61,
#   'attempted_three_point_field_goals': 224,
#   'made_free_throws': 105,
#   'attempted_free_throws': 140,
#   'offensive_rebounds': 42,
#   'defensive_rebounds': 157,
#   'assists': 109,
#   'steals': 84,
#   'blocks': 19,
#   'turnovers': 78,
#   'personal_fouls': 168,
#   'points': 590},
#  {'slug': 'brookaa01',
#   'name': 'Aaron Brooks',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 31,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 69,
#   'games_started': 0,
#   'minutes_played': 1108,
#   'made_field_goals': 188,
#   'attempted_field_goals': 469,
#   'made_three_point_field_goals': 66,
#   'attempted_three_point_field_goals': 185,
#   'made_free_throws': 49,
#   'attempted_free_throws': 64,
#   'offensive_rebounds': 21,
#   'defensive_rebounds': 80,
#   'assists': 180,
#   'steals': 30,
#   'blocks': 10,
#   'turnovers': 82,
#   'personal_fouls': 132,
#   'points': 491},
#  {'slug': 'brownan02',
#   'name': 'Anthony Brown',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 23,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 29,
#   'games_started': 11,
#   'minutes_played': 599,
#   'made_field_goals': 39,
#   'attempted_field_goals': 126,
#   'made_three_point_field_goals': 20,
#   'attempted_three_point_field_goals': 70,
#   'made_free_throws': 17,
#   'attempted_free_throws': 20,
#   'offensive_rebounds': 9,
#   'defensive_rebounds': 61,
#   'assists': 19,
#   'steals': 14,
#   'blocks': 5,
#   'turnovers': 15,
#   'personal_fouls': 34,
#   'points': 115},
#  {'slug': 'brownlo01',
#   'name': 'Lorenzo Brown',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 25,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 8,
#   'games_started': 0,
#   'minutes_played': 61,
#   'made_field_goals': 8,
#   'attempted_field_goals': 25,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 8,
#   'made_free_throws': 3,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 0,
#   'defensive_rebounds': 7,
#   'assists': 11,
#   'steals': 3,
#   'blocks': 1,
#   'turnovers': 9,
#   'personal_fouls': 4,
#   'points': 20},
#  {'slug': 'brownma02',
#   'name': 'Markel Brown',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 24,
#   'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'games_played': 62,
#   'games_started': 6,
#   'minutes_played': 982,
#   'made_field_goals': 127,
#   'attempted_field_goals': 322,
#   'made_three_point_field_goals': 38,
#   'attempted_three_point_field_goals': 121,
#   'made_free_throws': 71,
#   'attempted_free_throws': 94,
#   'offensive_rebounds': 23,
#   'defensive_rebounds': 99,
#   'assists': 91,
#   'steals': 38,
#   'blocks': 15,
#   'turnovers': 54,
#   'personal_fouls': 94,
#   'points': 363},
#  {'slug': 'bryanko01',
#   'name': 'Kobe Bryant',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 37,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 66,
#   'games_started': 66,
#   'minutes_played': 1863,
#   'made_field_goals': 398,
#   'attempted_field_goals': 1113,
#   'made_three_point_field_goals': 133,
#   'attempted_three_point_field_goals': 467,
#   'made_free_throws': 232,
#   'attempted_free_throws': 281,
#   'offensive_rebounds': 41,
#   'defensive_rebounds': 206,
#   'assists': 184,
#   'steals': 62,
#   'blocks': 13,
#   'turnovers': 129,
#   'personal_fouls': 115,
#   'points': 1161},
#  {'slug': 'budinch01',
#   'name': 'Chase Budinger',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 27,
#   'team': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'games_played': 49,
#   'games_started': 2,
#   'minutes_played': 729,
#   'made_field_goals': 81,
#   'attempted_field_goals': 194,
#   'made_three_point_field_goals': 20,
#   'attempted_three_point_field_goals': 69,
#   'made_free_throws': 34,
#   'attempted_free_throws': 48,
#   'offensive_rebounds': 31,
#   'defensive_rebounds': 90,
#   'assists': 49,
#   'steals': 29,
#   'blocks': 9,
#   'turnovers': 31,
#   'personal_fouls': 46,
#   'points': 216},
#  {'slug': 'budinch01',
#   'name': 'Chase Budinger',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 27,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 17,
#   'games_started': 0,
#   'minutes_played': 200,
#   'made_field_goals': 23,
#   'attempted_field_goals': 45,
#   'made_three_point_field_goals': 4,
#   'attempted_three_point_field_goals': 17,
#   'made_free_throws': 5,
#   'attempted_free_throws': 8,
#   'offensive_rebounds': 12,
#   'defensive_rebounds': 17,
#   'assists': 15,
#   'steals': 3,
#   'blocks': 1,
#   'turnovers': 13,
#   'personal_fouls': 16,
#   'points': 55},
#  {'slug': 'bullore01',
#   'name': 'Reggie Bullock',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 24,
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'games_played': 37,
#   'games_started': 0,
#   'minutes_played': 429,
#   'made_field_goals': 43,
#   'attempted_field_goals': 98,
#   'made_three_point_field_goals': 22,
#   'attempted_three_point_field_goals': 53,
#   'made_free_throws': 14,
#   'attempted_free_throws': 15,
#   'offensive_rebounds': 14,
#   'defensive_rebounds': 54,
#   'assists': 27,
#   'steals': 10,
#   'blocks': 2,
#   'turnovers': 8,
#   'personal_fouls': 29,
#   'points': 122},
#  {'slug': 'burketr01',
#   'name': 'Trey Burke',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 23,
#   'team': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'games_played': 64,
#   'games_started': 0,
#   'minutes_played': 1366,
#   'made_field_goals': 262,
#   'attempted_field_goals': 634,
#   'made_three_point_field_goals': 88,
#   'attempted_three_point_field_goals': 256,
#   'made_free_throws': 67,
#   'attempted_free_throws': 82,
#   'offensive_rebounds': 18,
#   'defensive_rebounds': 94,
#   'assists': 148,
#   'steals': 35,
#   'blocks': 6,
#   'turnovers': 80,
#   'personal_fouls': 86,
#   'points': 679},
#  {'slug': 'burksal01',
#   'name': 'Alec Burks',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 24,
#   'team': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'games_played': 31,
#   'games_started': 3,
#   'minutes_played': 797,
#   'made_field_goals': 137,
#   'attempted_field_goals': 334,
#   'made_three_point_field_goals': 32,
#   'attempted_three_point_field_goals': 79,
#   'made_free_throws': 106,
#   'attempted_free_throws': 141,
#   'offensive_rebounds': 16,
#   'defensive_rebounds': 93,
#   'assists': 63,
#   'steals': 18,
#   'blocks': 4,
#   'turnovers': 51,
#   'personal_fouls': 71,
#   'points': 412},
#  {'slug': 'butleca01',
#   'name': 'Caron Butler',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 35,
#   'team': <Team.SACRAMENTO_KINGS: 'SACRAMENTO KINGS'>,
#   'games_played': 17,
#   'games_started': 1,
#   'minutes_played': 176,
#   'made_field_goals': 25,
#   'attempted_field_goals': 59,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 18,
#   'made_free_throws': 10,
#   'attempted_free_throws': 12,
#   'offensive_rebounds': 5,
#   'defensive_rebounds': 17,
#   'assists': 10,
#   'steals': 9,
#   'blocks': 1,
#   'turnovers': 3,
#   'personal_fouls': 19,
#   'points': 63},
#  {'slug': 'butleji01',
#   'name': 'Jimmy Butler',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 26,
#   'team': <Team.CHICAGO_BULLS: 'CHICAGO BULLS'>,
#   'games_played': 67,
#   'games_started': 67,
#   'minutes_played': 2474,
#   'made_field_goals': 470,
#   'attempted_field_goals': 1035,
#   'made_three_point_field_goals': 64,
#   'attempted_three_point_field_goals': 205,
#   'made_free_throws': 395,
#   'attempted_free_throws': 475,
#   'offensive_rebounds': 79,
#   'defensive_rebounds': 279,
#   'assists': 321,
#   'steals': 110,
#   'blocks': 43,
#   'turnovers': 132,
#   'personal_fouls': 124,
#   'points': 1399},
#  {'slug': 'butlera01',
#   'name': 'Rasual Butler',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 36,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 46,
#   'games_started': 0,
#   'minutes_played': 432,
#   'made_field_goals': 49,
#   'attempted_field_goals': 104,
#   'made_three_point_field_goals': 15,
#   'attempted_three_point_field_goals': 49,
#   'made_free_throws': 11,
#   'attempted_free_throws': 16,
#   'offensive_rebounds': 3,
#   'defensive_rebounds': 53,
#   'assists': 24,
#   'steals': 13,
#   'blocks': 23,
#   'turnovers': 8,
#   'personal_fouls': 11,
#   'points': 124},
#  {'slug': 'cabocbr01',
#   'name': 'Bruno Caboclo',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 20,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 6,
#   'games_started': 1,
#   'minutes_played': 43,
#   'made_field_goals': 1,
#   'attempted_field_goals': 12,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 7,
#   'made_free_throws': 0,
#   'attempted_free_throws': 0,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 1,
#   'assists': 1,
#   'steals': 2,
#   'blocks': 1,
#   'turnovers': 4,
#   'personal_fouls': 2,
#   'points': 3},
#  {'slug': 'caldejo01',
#   'name': 'José Calderón',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 34,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 72,
#   'games_started': 72,
#   'minutes_played': 2024,
#   'made_field_goals': 209,
#   'attempted_field_goals': 455,
#   'made_three_point_field_goals': 84,
#   'attempted_three_point_field_goals': 203,
#   'made_free_throws': 42,
#   'attempted_free_throws': 48,
#   'offensive_rebounds': 22,
#   'defensive_rebounds': 207,
#   'assists': 298,
#   'steals': 63,
#   'blocks': 7,
#   'turnovers': 87,
#   'personal_fouls': 135,
#   'points': 544},
#  {'slug': 'caldwke01',
#   'name': 'Kentavious Caldwell-Pope',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 22,
#   'team': <Team.DETROIT_PISTONS: 'DETROIT PISTONS'>,
#   'games_played': 76,
#   'games_started': 76,
#   'minutes_played': 2789,
#   'made_field_goals': 403,
#   'attempted_field_goals': 960,
#   'made_three_point_field_goals': 114,
#   'attempted_three_point_field_goals': 369,
#   'made_free_throws': 185,
#   'attempted_free_throws': 228,
#   'offensive_rebounds': 70,
#   'defensive_rebounds': 212,
#   'assists': 138,
#   'steals': 110,
#   'blocks': 17,
#   'turnovers': 105,
#   'personal_fouls': 167,
#   'points': 1105},
# ...
#   'made_free_throws': 1,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 11,
#   'assists': 2,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 4,
#   'personal_fouls': 7,
#   'points': 17},
#  {'slug': 'westda01',
#   'name': 'David West',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 35,
#   'team': <Team.SAN_ANTONIO_SPURS: 'SAN ANTONIO SPURS'>,
#   'games_played': 78,
#   'games_started': 19,
#   'minutes_played': 1404,
#   'made_field_goals': 244,
#   'attempted_field_goals': 448,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 7,
#   'made_free_throws': 63,
#   'attempted_free_throws': 80,
#   'offensive_rebounds': 72,
#   'defensive_rebounds': 237,
#   'assists': 143,
#   'steals': 44,
#   'blocks': 55,
#   'turnovers': 68,
#   'personal_fouls': 142,
#   'points': 554},
#  {'slug': 'westbru01',
#   'name': 'Russell Westbrook',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 27,
#   'team': <Team.OKLAHOMA_CITY_THUNDER: 'OKLAHOMA CITY THUNDER'>,
#   'games_played': 80,
#   'games_started': 80,
#   'minutes_played': 2750,
#   'made_field_goals': 656,
#   'attempted_field_goals': 1444,
#   'made_three_point_field_goals': 101,
#   'attempted_three_point_field_goals': 341,
#   'made_free_throws': 465,
#   'attempted_free_throws': 573,
#   'offensive_rebounds': 145,
#   'defensive_rebounds': 481,
#   'assists': 834,
#   'steals': 163,
#   'blocks': 20,
#   'turnovers': 342,
#   'personal_fouls': 200,
#   'points': 1878},
#  {'slug': 'whiteha01',
#   'name': 'Hassan Whiteside',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 26,
#   'team': <Team.MIAMI_HEAT: 'MIAMI HEAT'>,
#   'games_played': 73,
#   'games_started': 43,
#   'minutes_played': 2125,
#   'made_field_goals': 413,
#   'attempted_field_goals': 682,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 214,
#   'attempted_free_throws': 329,
#   'offensive_rebounds': 238,
#   'defensive_rebounds': 627,
#   'assists': 30,
#   'steals': 44,
#   'blocks': 269,
#   'turnovers': 137,
#   'personal_fouls': 201,
#   'points': 1040},
#  {'slug': 'whittsh01',
#   'name': 'Shayne Whittington',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 24,
#   'team': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'games_played': 7,
#   'games_started': 0,
#   'minutes_played': 41,
#   'made_field_goals': 5,
#   'attempted_field_goals': 11,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 1,
#   'attempted_free_throws': 2,
#   'offensive_rebounds': 5,
#   'defensive_rebounds': 7,
#   'assists': 3,
#   'steals': 1,
#   'blocks': 1,
#   'turnovers': 5,
#   'personal_fouls': 7,
#   'points': 11},
#  {'slug': 'wiggian01',
#   'name': 'Andrew Wiggins',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 20,
#   'team': <Team.MINNESOTA_TIMBERWOLVES: 'MINNESOTA TIMBERWOLVES'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2845,
#   'made_field_goals': 594,
#   'attempted_field_goals': 1294,
#   'made_three_point_field_goals': 57,
#   'attempted_three_point_field_goals': 190,
#   'made_free_throws': 430,
#   'attempted_free_throws': 565,
#   'offensive_rebounds': 105,
#   'defensive_rebounds': 186,
#   'assists': 164,
#   'steals': 78,
#   'blocks': 46,
#   'turnovers': 182,
#   'personal_fouls': 165,
#   'points': 1675},
#  {'slug': 'wilcocj01',
#   'name': 'C.J. Wilcox',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 25,
#   'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'games_played': 23,
#   'games_started': 0,
#   'minutes_played': 167,
#   'made_field_goals': 26,
#   'attempted_field_goals': 66,
#   'made_three_point_field_goals': 9,
#   'attempted_three_point_field_goals': 23,
#   'made_free_throws': 9,
#   'attempted_free_throws': 12,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 11,
#   'assists': 10,
#   'steals': 10,
#   'blocks': 2,
#   'turnovers': 2,
#   'personal_fouls': 15,
#   'points': 70},
#  {'slug': 'willial03',
#   'name': 'Alan Williams',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 23,
#   'team': <Team.PHOENIX_SUNS: 'PHOENIX SUNS'>,
#   'games_played': 10,
#   'games_started': 0,
#   'minutes_played': 68,
#   'made_field_goals': 10,
#   'attempted_field_goals': 24,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 9,
#   'attempted_free_throws': 14,
#   'offensive_rebounds': 14,
#   'defensive_rebounds': 24,
#   'assists': 5,
#   'steals': 4,
#   'blocks': 5,
#   'turnovers': 6,
#   'personal_fouls': 15,
#   'points': 29},
#  {'slug': 'willide01',
#   'name': 'Deron Williams',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 31,
#   'team': <Team.DALLAS_MAVERICKS: 'DALLAS MAVERICKS'>,
#   'games_played': 65,
#   'games_started': 63,
#   'minutes_played': 2106,
#   'made_field_goals': 321,
#   'attempted_field_goals': 775,
#   'made_three_point_field_goals': 97,
#   'attempted_three_point_field_goals': 282,
#   'made_free_throws': 179,
#   'attempted_free_throws': 206,
#   'offensive_rebounds': 19,
#   'defensive_rebounds': 171,
#   'assists': 378,
#   'steals': 61,
#   'blocks': 14,
#   'turnovers': 150,
#   'personal_fouls': 155,
#   'points': 918},
#  {'slug': 'willide02',
#   'name': 'Derrick Williams',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 24,
#   'team': <Team.NEW_YORK_KNICKS: 'NEW YORK KNICKS'>,
#   'games_played': 80,
#   'games_started': 9,
#   'minutes_played': 1435,
#   'made_field_goals': 254,
#   'attempted_field_goals': 565,
#   'made_three_point_field_goals': 44,
#   'attempted_three_point_field_goals': 150,
#   'made_free_throws': 194,
#   'attempted_free_throws': 256,
#   'offensive_rebounds': 47,
#   'defensive_rebounds': 249,
#   'assists': 75,
#   'steals': 29,
#   'blocks': 9,
#   'turnovers': 61,
#   'personal_fouls': 69,
#   'points': 746},
#  {'slug': 'williel01',
#   'name': 'Elliot Williams',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 26,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 5,
#   'games_started': 0,
#   'minutes_played': 45,
#   'made_field_goals': 2,
#   'attempted_field_goals': 10,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 4,
#   'made_free_throws': 3,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 1,
#   'defensive_rebounds': 3,
#   'assists': 4,
#   'steals': 0,
#   'blocks': 0,
#   'turnovers': 1,
#   'personal_fouls': 2,
#   'points': 8},
#  {'slug': 'willilo02',
#   'name': 'Lou Williams',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 29,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 67,
#   'games_started': 35,
#   'minutes_played': 1907,
#   'made_field_goals': 283,
#   'attempted_field_goals': 693,
#   'made_three_point_field_goals': 110,
#   'attempted_three_point_field_goals': 320,
#   'made_free_throws': 352,
#   'attempted_free_throws': 424,
#   'offensive_rebounds': 31,
#   'defensive_rebounds': 138,
#   'assists': 167,
#   'steals': 62,
#   'blocks': 19,
#   'turnovers': 107,
#   'personal_fouls': 107,
#   'points': 1028},
#  {'slug': 'willima02',
#   'name': 'Marvin Williams',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 29,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 81,
#   'games_started': 81,
#   'minutes_played': 2338,
#   'made_field_goals': 338,
#   'attempted_field_goals': 747,
#   'made_three_point_field_goals': 152,
#   'attempted_three_point_field_goals': 378,
#   'made_free_throws': 120,
#   'attempted_free_throws': 144,
#   'offensive_rebounds': 127,
#   'defensive_rebounds': 394,
#   'assists': 110,
#   'steals': 58,
#   'blocks': 77,
#   'turnovers': 62,
#   'personal_fouls': 133,
#   'points': 948},
#  {'slug': 'willima01',
#   'name': 'Mo Williams',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 33,
#   'team': <Team.CLEVELAND_CAVALIERS: 'CLEVELAND CAVALIERS'>,
#   'games_played': 41,
#   'games_started': 14,
#   'minutes_played': 748,
#   'made_field_goals': 132,
#   'attempted_field_goals': 302,
#   'made_three_point_field_goals': 36,
#   'attempted_three_point_field_goals': 102,
#   'made_free_throws': 38,
#   'attempted_free_throws': 42,
#   'offensive_rebounds': 6,
#   'defensive_rebounds': 66,
#   'assists': 98,
#   'steals': 14,
#   'blocks': 5,
#   'turnovers': 57,
#   'personal_fouls': 60,
#   'points': 338},
#  {'slug': 'winslju01',
#   'name': 'Justise Winslow',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 19,
#   'team': <Team.MIAMI_HEAT: 'MIAMI HEAT'>,
#   'games_played': 78,
#   'games_started': 8,
#   'minutes_played': 2232,
#   'made_field_goals': 195,
#   'attempted_field_goals': 462,
#   'made_three_point_field_goals': 32,
#   'attempted_three_point_field_goals': 116,
#   'made_free_throws': 80,
#   'attempted_free_throws': 117,
#   'offensive_rebounds': 81,
#   'defensive_rebounds': 322,
#   'assists': 117,
#   'steals': 68,
#   'blocks': 26,
#   'turnovers': 95,
#   'personal_fouls': 184,
#   'points': 502},
#  {'slug': 'witheje01',
#   'name': 'Jeff Withey',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 25,
#   'team': <Team.UTAH_JAZZ: 'UTAH JAZZ'>,
#   'games_played': 51,
#   'games_started': 10,
#   'minutes_played': 658,
#   'made_field_goals': 87,
#   'attempted_field_goals': 162,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 2,
#   'made_free_throws': 43,
#   'attempted_free_throws': 59,
#   'offensive_rebounds': 56,
#   'defensive_rebounds': 117,
#   'assists': 20,
#   'steals': 21,
#   'blocks': 53,
#   'turnovers': 28,
#   'personal_fouls': 75,
#   'points': 217},
#  {'slug': 'woodch01',
#   'name': 'Christian Wood',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 20,
#   'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'games_played': 17,
#   'games_started': 0,
#   'minutes_played': 145,
#   'made_field_goals': 22,
#   'attempted_field_goals': 53,
#   'made_three_point_field_goals': 4,
#   'attempted_three_point_field_goals': 11,
#   'made_free_throws': 13,
#   'attempted_free_throws': 21,
#   'offensive_rebounds': 13,
#   'defensive_rebounds': 25,
#   'assists': 3,
#   'steals': 5,
#   'blocks': 7,
#   'turnovers': 2,
#   'personal_fouls': 11,
#   'points': 61},
#  {'slug': 'artesro01',
#   'name': 'Metta World Peace',
#   'positions': [<Position.SMALL_FORWARD: 'SMALL FORWARD'>],
#   'age': 36,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 35,
#   'games_started': 5,
#   'minutes_played': 590,
#   'made_field_goals': 55,
#   'attempted_field_goals': 177,
#   'made_three_point_field_goals': 26,
#   'attempted_three_point_field_goals': 84,
#   'made_free_throws': 40,
#   'attempted_free_throws': 57,
#   'offensive_rebounds': 19,
#   'defensive_rebounds': 70,
#   'assists': 27,
#   'steals': 22,
#   'blocks': 11,
#   'turnovers': 15,
#   'personal_fouls': 67,
#   'points': 176},
#  {'slug': 'wrighbr03',
#   'name': 'Brandan Wright',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 28,
#   'team': <Team.MEMPHIS_GRIZZLIES: 'MEMPHIS GRIZZLIES'>,
#   'games_played': 12,
#   'games_started': 2,
#   'minutes_played': 212,
#   'made_field_goals': 35,
#   'attempted_field_goals': 52,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 13,
#   'attempted_free_throws': 24,
#   'offensive_rebounds': 14,
#   'defensive_rebounds': 29,
#   'assists': 6,
#   'steals': 5,
#   'blocks': 15,
#   'turnovers': 10,
#   'personal_fouls': 21,
#   'points': 83},
#  {'slug': 'wrighde01',
#   'name': 'Delon Wright',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 23,
#   'team': <Team.TORONTO_RAPTORS: 'TORONTO RAPTORS'>,
#   'games_played': 27,
#   'games_started': 1,
#   'minutes_played': 229,
#   'made_field_goals': 36,
#   'attempted_field_goals': 80,
#   'made_three_point_field_goals': 5,
#   'attempted_three_point_field_goals': 13,
#   'made_free_throws': 26,
#   'attempted_free_throws': 35,
#   'offensive_rebounds': 8,
#   'defensive_rebounds': 29,
#   'assists': 31,
#   'steals': 8,
#   'blocks': 3,
#   'turnovers': 16,
#   'personal_fouls': 7,
#   'points': 103},
#  {'slug': 'wroteto01',
#   'name': 'Tony Wroten',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 22,
#   'team': <Team.PHILADELPHIA_76ERS: 'PHILADELPHIA 76ERS'>,
#   'games_played': 8,
#   'games_started': 3,
#   'minutes_played': 144,
#   'made_field_goals': 22,
#   'attempted_field_goals': 65,
#   'made_three_point_field_goals': 3,
#   'attempted_three_point_field_goals': 17,
#   'made_free_throws': 20,
#   'attempted_free_throws': 37,
#   'offensive_rebounds': 2,
#   'defensive_rebounds': 19,
#   'assists': 20,
#   'steals': 3,
#   'blocks': 0,
#   'turnovers': 29,
#   'personal_fouls': 11,
#   'points': 67},
#  {'slug': 'youngja01',
#   'name': 'James Young',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 20,
#   'team': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#   'games_played': 29,
#   'games_started': 0,
#   'minutes_played': 199,
#   'made_field_goals': 11,
#   'attempted_field_goals': 36,
#   'made_three_point_field_goals': 6,
#   'attempted_three_point_field_goals': 26,
#   'made_free_throws': 1,
#   'attempted_free_throws': 4,
#   'offensive_rebounds': 4,
#   'defensive_rebounds': 22,
#   'assists': 9,
#   'steals': 6,
#   'blocks': 1,
#   'turnovers': 5,
#   'personal_fouls': 17,
#   'points': 29},
#  {'slug': 'youngjo01',
#   'name': 'Joe Young',
#   'positions': [<Position.POINT_GUARD: 'POINT GUARD'>],
#   'age': 23,
#   'team': <Team.INDIANA_PACERS: 'INDIANA PACERS'>,
#   'games_played': 41,
#   'games_started': 0,
#   'minutes_played': 384,
#   'made_field_goals': 62,
#   'attempted_field_goals': 169,
#   'made_three_point_field_goals': 10,
#   'attempted_three_point_field_goals': 46,
#   'made_free_throws': 20,
#   'attempted_free_throws': 25,
#   'offensive_rebounds': 6,
#   'defensive_rebounds': 44,
#   'assists': 65,
#   'steals': 15,
#   'blocks': 0,
#   'turnovers': 33,
#   'personal_fouls': 30,
#   'points': 154},
#  {'slug': 'youngni01',
#   'name': 'Nick Young',
#   'positions': [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>],
#   'age': 30,
#   'team': <Team.LOS_ANGELES_LAKERS: 'LOS ANGELES LAKERS'>,
#   'games_played': 54,
#   'games_started': 2,
#   'minutes_played': 1033,
#   'made_field_goals': 126,
#   'attempted_field_goals': 372,
#   'made_three_point_field_goals': 77,
#   'attempted_three_point_field_goals': 237,
#   'made_free_throws': 63,
#   'attempted_free_throws': 76,
#   'offensive_rebounds': 14,
#   'defensive_rebounds': 83,
#   'assists': 34,
#   'steals': 23,
#   'blocks': 7,
#   'turnovers': 30,
#   'personal_fouls': 50,
#   'points': 392},
#  {'slug': 'youngth01',
#   'name': 'Thaddeus Young',
#   'positions': [<Position.POWER_FORWARD: 'POWER FORWARD'>],
#   'age': 27,
#   'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'games_played': 73,
#   'games_started': 73,
#   'minutes_played': 2407,
#   'made_field_goals': 495,
#   'attempted_field_goals': 963,
#   'made_three_point_field_goals': 7,
#   'attempted_three_point_field_goals': 30,
#   'made_free_throws': 105,
#   'attempted_free_throws': 163,
#   'offensive_rebounds': 176,
#   'defensive_rebounds': 484,
#   'assists': 136,
#   'steals': 112,
#   'blocks': 37,
#   'turnovers': 136,
#   'personal_fouls': 182,
#   'points': 1102},
#  {'slug': 'zelleco01',
#   'name': 'Cody Zeller',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 23,
#   'team': <Team.CHARLOTTE_HORNETS: 'CHARLOTTE HORNETS'>,
#   'games_played': 73,
#   'games_started': 60,
#   'minutes_played': 1774,
#   'made_field_goals': 231,
#   'attempted_field_goals': 437,
#   'made_three_point_field_goals': 1,
#   'attempted_three_point_field_goals': 10,
#   'made_free_throws': 175,
#   'attempted_free_throws': 232,
#   'offensive_rebounds': 138,
#   'defensive_rebounds': 317,
#   'assists': 71,
#   'steals': 57,
#   'blocks': 63,
#   'turnovers': 68,
#   'personal_fouls': 204,
#   'points': 638},
#  {'slug': 'zellety01',
#   'name': 'Tyler Zeller',
#   'positions': [<Position.CENTER: 'CENTER'>],
#   'age': 26,
#   'team': <Team.BOSTON_CELTICS: 'BOSTON CELTICS'>,
#   'games_played': 60,
#   'games_started': 3,
#   'minutes_played': 710,
#   'made_field_goals': 138,
#   'attempted_field_goals': 290,
#   'made_three_point_field_goals': 0,
#   'attempted_three_point_field_goals': 0,
#   'made_free_throws': 88,
#   'attempted_free_throws': 108,
#   'offensive_rebounds': 62,
#   'defensive_rebounds': 116,
#   'assists': 29,
#   'steals': 10,
#   'blocks': 22,
#   'turnovers': 46,
#   'personal_fouls': 97,
#   'points': 364}]

# %%
name_list = []
for i, player_stats_2016 in enumerate(stats_2016):
    print(i, player_stats_2016["name"])
    name_list.append(player_stats_2016["name"])
    shot_efficiency_stats_df.loc[i, "name"] = player_stats_2016["name"]
    shot_efficiency_stats_df.loc[i, "attempted_field_goals"] = player_stats_2016["attempted_field_goals"]
    if shot_efficiency_stats_df.loc[i, "attempted_field_goals"] == 0:
        continue
    eFG = (player_stats_2016["made_field_goals"]+0.5*player_stats_2016["made_three_point_field_goals"])/player_stats_2016["attempted_field_goals"]*100
    shot_efficiency_stats_df.loc[i, "eFG%"] = Decimal(str(eFG)).quantize(Decimal('0.1'), rounding=ROUND_HALF_UP)
shot_efficiency_stats_df.index = name_list
# Out:
# 0 Quincy Acy
# 1 Jordan Adams
# 2 Steven Adams
# 3 Arron Afflalo
# 4 Alexis Ajinça
# 5 Cole Aldrich
# 6 LaMarcus Aldridge
# 7 Cliff Alexander
# 8 Lavoy Allen
# 9 Tony Allen
# 10 Al-Farouq Aminu
# 11 Lou Amundson
# 12 Chris Andersen
# 13 Chris Andersen
# 14 Alan Anderson
# 15 James Anderson
# 16 Justin Anderson
# 17 Kyle Anderson
# 18 Ryan Anderson
# 19 Giannis Antetokounmpo
# 20 Thanasis Antetokounmpo
# 21 Carmelo Anthony
# 22 Joel Anthony
# 23 Keith Appling
# 24 Trevor Ariza
# 25 Darrell Arthur
# 26 Ömer Aşık
# 27 D.J. Augustin
# 28 D.J. Augustin
# 29 Jeff Ayres
# 30 Luke Babbitt
# 31 Cameron Bairstow
# 32 Leandro Barbosa
# 33 J.J. Barea
# 34 Andrea Bargnani
# 35 Harrison Barnes
# 36 Matt Barnes
# 37 Will Barton
# 38 Brandon Bass
# 39 Nicolas Batum
# 40 Jerryd Bayless
# 41 Aron Baynes
# 42 Kent Bazemore
# 43 Bradley Beal
# 44 Michael Beasley
# 45 Marco Belinelli
# 46 Anthony Bennett
# 47 Patrick Beverley
# 48 Bismack Biyombo
# 49 Nemanja Bjelica
# 50 Tarik Black
# 51 DeJuan Blair
# 52 Steve Blake
# 53 Eric Bledsoe
# 54 Bojan Bogdanović
# 55 Andrew Bogut
# 56 Matt Bonner
# 57 Devin Booker
# 58 Trevor Booker
# 59 Chris Bosh
# 60 Avery Bradley
# 61 Elton Brand
# 62 Corey Brewer
# 63 Aaron Brooks
# 64 Anthony Brown
# 65 Lorenzo Brown
# 66 Markel Brown
# 67 Kobe Bryant
# 68 Chase Budinger
# 69 Chase Budinger
# 70 Reggie Bullock
# 71 Trey Burke
# 72 Alec Burks
# 73 Caron Butler
# 74 Jimmy Butler
# 75 Rasual Butler
# 76 Bruno Caboclo
# 77 José Calderón
# 78 Kentavious Caldwell-Pope
# 79 Isaiah Canaan
# 80 Clint Capela
# 81 DeMarre Carroll
# 82 Vince Carter
# 83 Michael Carter-Williams
# 84 Omri Casspi
# 85 Willie Cauley-Stein
# 86 Mario Chalmers
# 87 Mario Chalmers
# 88 Tyson Chandler
# 89 Rakeem Christmas
# 90 Ian Clark
# 91 Coty Clarke
# 92 Jordan Clarkson
# 93 Norris Cole
# 94 Darren Collison
# 95 Nick Collison
# 96 Mike Conley
# 97 Pat Connaughton
# 98 Chris Copeland
# 99 Bryce Cotton
# 100 Bryce Cotton
# 101 DeMarcus Cousins
# 102 Robert Covington
# 103 Allen Crabbe
# 104 Jamal Crawford
# 105 Jae Crowder
# 106 Dante Cunningham
# 107 Jared Cunningham
# 108 Jared Cunningham
# 109 Seth Curry
# 110 Stephen Curry
# 111 Troy Daniels
# 112 Anthony Davis
# 113 Ed Davis
# 114 Branden Dawson
# 115 Dewayne Dedmon
# 116 Bryce Dejean-Jones
# 117 Sam Dekker
# 118 Matthew Dellavedova
# 119 Luol Deng
# 120 DeMar DeRozan
# 121 Boris Diaw
# 122 Gorgui Dieng
# 123 Spencer Dinwiddie
# 124 Toney Douglas
# 125 Goran Dragić
# 126 Andre Drummond
# 127 Jared Dudley
# 128 Duje Dukan
# 129 Tim Duncan
# 130 Mike Dunleavy
# 131 Kevin Durant
# 132 Cleanthony Early
# 133 Jarell Eddie
# 134 Wayne Ellington
# 135 Monta Ellis
# 136 James Ennis III
# 137 James Ennis III
# 138 James Ennis III
# 139 Tyler Ennis
# 140 Jeremy Evans
# 141 Tyreke Evans
# 142 Festus Ezeli
# 143 Kenneth Faried
# 144 Jordan Farmar
# 145 Derrick Favors
# 146 Cristiano Felício
# 147 Raymond Felton
# 148 Evan Fournier
# 149 Randy Foye
# 150 Randy Foye
# 151 Tim Frazier
# 152 Tim Frazier
# 153 Jimmer Fredette
# 154 Jimmer Fredette
# 155 Enes Freedom
# 156 Channing Frye
# 157 Channing Frye
# 158 Danilo Gallinari
# 159 Langston Galloway
# 160 Kevin Garnett
# 161 Marc Gasol
# 162 Pau Gasol
# 163 Rudy Gay
# 164 Alonzo Gee
# 165 Paul George
# 166 Taj Gibson
# 167 Manu Ginóbili
# 168 Rudy Gobert
# 169 Drew Gooden
# 170 Archie Goodwin
# 171 Aaron Gordon
# 172 Eric Gordon
# 173 Marcin Gortat
# 174 Andrew Goudelock
# 175 Jerami Grant
# 176 Jerian Grant
# 177 Danny Green
# 178 Draymond Green
# 179 Erick Green
# 180 Erick Green
# 181 Gerald Green
# 182 JaMychal Green
# 183 Jeff Green
# 184 Jeff Green
# 185 Blake Griffin
# 186 Jorge Gutiérrez
# 187 P.J. Hairston
# 188 P.J. Hairston
# 189 Jordan Hamilton
# 190 Tyler Hansbrough
# 191 Tim Hardaway Jr.
# 192 James Harden
# 193 Maurice Harkless
# 194 Justin Harper
# 195 Montrezl Harrell
# 196 Devin Harris
# 197 Gary Harris
# 198 Joe Harris
# 199 Tobias Harris
# 200 Tobias Harris
# 201 Aaron Harrison
# 202 Udonis Haslem
# 203 Spencer Hawes
# 204 Chuck Hayes
# 205 Gordon Hayward
# 206 Gerald Henderson
# 207 John Henson
# 208 Mario Hezonja
# 209 Roy Hibbert
# 210 J.J. Hickson
# 211 J.J. Hickson
# 212 Nenê
# 213 George Hill
# 214 Jordan Hill
# 215 Solomon Hill
# 216 Darrun Hilliard
# 217 Kirk Hinrich
# 218 Kirk Hinrich
# 219 Jrue Holiday
# 220 Justin Holiday
# 221 Justin Holiday
# 222 Ryan Hollins
# 223 Ryan Hollins
# 224 Rondae Hollis-Jefferson
# 225 Richaun Holmes
# 226 Rodney Hood
# 227 Al Horford
# 228 Dwight Howard
# 229 Marcelo Huertas
# 230 Josh Huestis
# 231 Kris Humphries
# 232 Kris Humphries
# 233 Kris Humphries
# 234 R.J. Hunter
# 235 Serge Ibaka
# 236 Andre Iguodala
# 237 Ersan İlyasova
# 238 Ersan İlyasova
# 239 Joe Ingles
# 240 Damien Inglis
# 241 Kyrie Irving
# 242 Jarrett Jack
# 243 Reggie Jackson
# 244 LeBron James
# 245 Al Jefferson
# 246 Cory Jefferson
# 247 Richard Jefferson
# 248 John Jenkins
# 249 John Jenkins
# 250 Brandon Jennings
# 251 Brandon Jennings
# 252 Jonas Jerebko
# 253 Amir Johnson
# 254 Chris Johnson
# 255 James Johnson
# 256 Joe Johnson
# 257 Joe Johnson
# 258 Orlando Johnson
# 259 Orlando Johnson
# 260 Stanley Johnson
# 261 Tyler Johnson
# 262 Wesley Johnson
# 263 Nikola Jokić
# 264 Dahntay Jones
# 265 James Jones
# 266 Terrence Jones
# 267 Tyus Jones
# 268 DeAndre Jordan
# 269 Cory Joseph
# 270 Chris Kaman
# 271 Frank Kaminsky
# 272 Sergey Karasev
# 273 Sasha Kaun
# 274 Ryan Kelly
# 275 Michael Kidd-Gilchrist
# 276 Sean Kilpatrick
# 277 Sean Kilpatrick
# 278 Brandon Knight
# 279 Kyle Korver
# 280 Kosta Koufos
# 281 Jeremy Lamb
# 282 Carl Landry
# 283 Shane Larkin
# 284 Joffrey Lauvergne
# 285 Zach LaVine
# 286 Ty Lawson
# 287 Ty Lawson
# 288 Courtney Lee
# 289 Courtney Lee
# 290 David Lee
# 291 David Lee
# 292 Alex Len
# 293 Kawhi Leonard
# 294 Meyers Leonard
# 295 Jon Leuer
# 296 Damian Lillard
# 297 Jeremy Lin
# 298 Shaun Livingston
# 299 Kevon Looney
# 300 Brook Lopez
# 301 Robin Lopez
# 302 Kevin Love
# 303 Kyle Lowry
# 304 Trey Lyles
# 305 Shelvin Mack
# 306 Shelvin Mack
# 307 Ian Mahinmi
# 308 Devyn Marble
# 309 Boban Marjanović
# 310 Kendall Marshall
# 311 Jarell Martin
# 312 Kevin Martin
# 313 Kevin Martin
# 314 Wesley Matthews
# 315 O.J. Mayo
# 316 Luc Mbah a Moute
# 317 James Michael McAdoo
# 318 Ray McCallum
# 319 Ray McCallum
# 320 CJ McCollum
# 321 T.J. McConnell
# 322 Chris McCullough
# 323 K.J. McDaniels
# 324 Doug McDermott
# 325 Mitch McGary
# 326 JaVale McGee
# 327 Ben McLemore
# 328 Jordan McRae
# 329 Jordan McRae
# 330 Josh McRoberts
# 331 Jodie Meeks
# 332 Salah Mejri
# 333 Jordan Mickey
# 334 Khris Middleton
# 335 C.J. Miles
# 336 Andre Miller
# 337 Andre Miller
# 338 Mike Miller
# 339 Patty Mills
# 340 Elijah Millsap
# 341 Paul Millsap
# 342 Nikola Mirotić
# 343 Nazr Mohammed
# 344 Greg Monroe
# 345 Luis Montero
# 346 E'Twaun Moore
# 347 Eric Moreland
# 348 Marcus Morris
# 349 Markieff Morris
# 350 Markieff Morris
# 351 Anthony Morrow
# 352 Donatas Motiejūnas
# 353 Timofey Mozgov
# 354 Emmanuel Mudiay
# 355 Shabazz Muhammad
# 356 Xavier Munford
# 357 Mike Muscala
# 358 Larry Nance Jr.
# 359 Shabazz Napier
# 360 Gary Neal
# 361 Jameer Nelson
# 362 Raul Neto
# 363 Andrew Nicholson
# 364 Joakim Noah
# 365 Nerlens Noel
# 366 Lucas Nogueira
# 367 Steve Novak
# 368 Steve Novak
# 369 Dirk Nowitzki
# 370 Jusuf Nurkić
# 371 J.J. O'Brien
# 372 Johnny O'Bryant
# 373 Kyle O'Quinn
# 374 Jahlil Okafor
# 375 Victor Oladipo
# 376 Kelly Olynyk
# 377 Kelly Oubre Jr.
# 378 Zaza Pachulia
# 379 Kostas Papanikolaou
# 380 Jabari Parker
# 381 Tony Parker
# 382 Chandler Parsons
# 383 Lamar Patterson
# 384 Patrick Patterson
# 385 Chris Paul
# 386 Adreian Payne
# 387 Cameron Payne
# 388 Elfrid Payton
# 389 Nikola Peković
# 390 Kendrick Perkins
# 391 Paul Pierce
# 392 Tibor Pleiß
# 393 Mason Plumlee
# 394 Miles Plumlee
# 395 Otto Porter Jr.
# 396 Bobby Portis
# 397 Kristaps Porziņģis
# 398 Dwight Powell
# 399 Norman Powell
# 400 Phil Pressey
# 401 Phil Pressey
# 402 Ronnie Price
# 403 Pablo Prigioni
# 404 Tayshaun Prince
# 405 Julius Randle
# 406 Zach Randolph
# 407 JJ Redick
# 408 Willie Reed
# 409 Josh Richardson
# 410 Austin Rivers
# 411 Andre Roberson
# 412 Brian Roberts
# 413 Brian Roberts
# 414 Glenn Robinson III
# 415 Nate Robinson
# 416 Thomas Robinson
# 417 Rajon Rondo
# 418 Derrick Rose
# 419 Terrence Ross
# 420 Terry Rozier
# 421 Ricky Rubio
# 422 Damjan Rudež
# 423 Brandon Rush
# 424 D'Angelo Russell
# 425 Robert Sacre
# 426 JaKarr Sampson
# 427 JaKarr Sampson
# 428 Dennis Schröder
# 429 Luis Scola
# 430 Mike Scott
# 431 Thabo Sefolosha
# 432 Kevin Séraphin
# 433 Ramon Sessions
# 434 Iman Shumpert
# 435 Jonathon Simmons
# 436 Henry Sims
# 437 Kyle Singler
# 438 Donald Sloan
# 439 Marcus Smart
# 440 Greg Smith
# 441 Ish Smith
# 442 Ish Smith
# 443 J.R. Smith
# 444 Jason Smith
# 445 Josh Smith
# 446 Josh Smith
# 447 Russ Smith
# 448 Tony Snell
# 449 Marreese Speights
# 450 Tiago Splitter
# 451 Nik Stauskas
# 452 Lance Stephenson
# 453 Lance Stephenson
# 454 Alex Stepheson
# 455 Alex Stepheson
# 456 Jarnell Stokes
# 457 Jarnell Stokes
# 458 Amar'e Stoudemire
# 459 Rodney Stuckey
# 460 Jared Sullinger
# 461 Edy Tavares
# 462 Jeff Teague
# 463 Mirza Teletović
# 464 Garrett Temple
# 465 Jason Terry
# 466 Isaiah Thomas
# 467 Lance Thomas
# 468 Hollis Thompson
# 469 Jason Thompson
# 470 Jason Thompson
# 471 Klay Thompson
# 472 Tristan Thompson
# 473 Marcus Thornton
# 474 Marcus Thornton
# 475 Anthony Tolliver
# 476 Axel Toupane
# 477 Karl-Anthony Towns
# 478 P.J. Tucker
# 479 Evan Turner
# 480 Myles Turner
# 481 Beno Udrih
# 482 Beno Udrih
# 483 Jonas Valančiūnas
# 484 Anderson Varejão
# 485 Anderson Varejão
# 486 Greivis Vásquez
# 487 Rashad Vaughn
# 488 Charlie Villanueva
# 489 Noah Vonleh
# 490 Nikola Vučević
# 491 Sasha Vujačić
# 492 Dwyane Wade
# 493 Dion Waiters
# 494 Kemba Walker
# 495 John Wall
# 496 T.J. Warren
# 497 C.J. Watson
# 498 Briante Weber
# 499 Briante Weber
# 500 Sonny Weems
# 501 Sonny Weems
# 502 David West
# 503 Russell Westbrook
# 504 Hassan Whiteside
# 505 Shayne Whittington
# 506 Andrew Wiggins
# 507 C.J. Wilcox
# 508 Alan Williams
# 509 Deron Williams
# 510 Derrick Williams
# 511 Elliot Williams
# 512 Lou Williams
# 513 Marvin Williams
# 514 Mo Williams
# 515 Justise Winslow
# 516 Jeff Withey
# 517 Christian Wood
# 518 Metta World Peace
# 519 Brandan Wright
# 520 Delon Wright
# 521 Tony Wroten
# 522 James Young
# 523 Joe Young
# 524 Nick Young
# 525 Thaddeus Young
# 526 Cody Zeller
# 527 Tyler Zeller

# %%
shot_efficiency_stats_df
# Out:
#                           name attempted_field_goals  eFG%  TS%
# Quincy Acy          Quincy Acy                   214  60.0  NaN
# Jordan Adams      Jordan Adams                     6  33.3  NaN
# Steven Adams      Steven Adams                   426  61.3  NaN
# Arron Afflalo    Arron Afflalo                   799  50.0  NaN
# Alexis Ajinça    Alexis Ajinça                   315  47.6  NaN
# ...                        ...                   ...   ...  ...
# Joe Young            Joe Young                   169  39.6  NaN
# Nick Young          Nick Young                   372  44.2  NaN
# Thaddeus Young  Thaddeus Young                   963  51.8  NaN
# Cody Zeller        Cody Zeller                   437  53.0  NaN
# Tyler Zeller      Tyler Zeller                   290  47.6  NaN
#
# [528 rows x 4 columns]

# %%
for i, player_advanced_stats_2016 in enumerate(advanced_stats_2016):
    shot_efficiency_stats_df.iloc[i, 3]  = player_advanced_stats_2016["true_shooting_percentage"]*100

# %%
transferred_player = shot_efficiency_stats_df[shot_efficiency_stats_df.duplicated('name', keep='first')]
transferred_player
# Out:
#                               name attempted_field_goals   eFG%    TS%
# Chris Andersen      Chris Andersen                    62   56.5   60.5
# D.J. Augustin        D.J. Augustin                   229   54.1   60.1
# Chase Budinger      Chase Budinger                    45   55.6   56.7
# Mario Chalmers      Mario Chalmers                   412   47.2   57.0
# Bryce Cotton          Bryce Cotton                     2  100.0  100.0
# Jared Cunningham  Jared Cunningham                    14   35.7   46.8
# James Ennis III    James Ennis III                    13   38.5   46.0
# James Ennis III    James Ennis III                   100   62.0   64.7
# Randy Foye              Randy Foye                   149   43.3   46.9
# Tim Frazier            Tim Frazier                   169   48.8   53.9
# Jimmer Fredette    Jimmer Fredette                     1  150.0  109.4
# Channing Frye        Channing Frye                   161   57.5   58.6
# Erick Green            Erick Green                    12   45.8   50.5
# Jeff Green              Jeff Green                   267   47.4   49.6
# P.J. Hairston        P.J. Hairston                   132   40.9   43.8
# Tobias Harris        Tobias Harris                   348   52.4   57.7
# J.J. Hickson          J.J. Hickson                    46   54.3   52.8
# Kirk Hinrich          Kirk Hinrich                    11   22.7   22.7
# Justin Holiday      Justin Holiday                   155   49.7   52.7
# Ryan Hollins          Ryan Hollins                    72   62.5   64.1
# Kris Humphries      Kris Humphries                    36   31.9   36.7
# Kris Humphries      Kris Humphries                   101   50.5   55.5
# Ersan İlyasova      Ersan İlyasova                   153   47.7   51.5
# John Jenkins          John Jenkins                    90   53.9   56.4
# Brandon Jennings  Brandon Jennings                   161   45.0   49.0
# Joe Johnson            Joe Johnson                   251   58.8   60.3
# Orlando Johnson    Orlando Johnson                    17   26.5   28.0
# Sean Kilpatrick    Sean Kilpatrick                   249   53.2   57.8
# Ty Lawson                Ty Lawson                    67   45.5   46.0
# Courtney Lee          Courtney Lee                   220   51.6   54.0
# David Lee                David Lee                   143   63.6   66.0
# Shelvin Mack          Shelvin Mack                   320   49.8   52.0
# Kevin Martin          Kevin Martin                    85   41.8   50.4
# Ray McCallum          Ray McCallum                    79   41.8   42.5
# Jordan McRae          Jordan McRae                    52   51.0   53.7
# Andre Miller          Andre Miller                    48   49.0   52.1
# Markieff Morris    Markieff Morris                   287   51.0   53.8
# Steve Novak            Steve Novak                     6   50.0   54.3
# Phil Pressey          Phil Pressey                    23   39.1   42.2
# Brian Roberts        Brian Roberts                    50   52.0   55.1
# JaKarr Sampson      JaKarr Sampson                   115   50.4   53.2
# Ish Smith                Ish Smith                   739   43.6   46.0
# Josh Smith              Josh Smith                   169   41.1   41.9
# Lance Stephenson  Lance Stephenson                   308   49.2   53.7
# Alex Stepheson      Alex Stepheson                    26   30.8   32.9
# Jarnell Stokes      Jarnell Stokes                     5   60.0   59.5
# Jason Thompson      Jason Thompson                    66   52.3   57.5
# Marcus Thornton    Marcus Thornton                   107   47.7   50.8
# Beno Udrih              Beno Udrih                   152   47.0   49.5
# Anderson Varejão  Anderson Varejão                    48   43.8   47.7
# Briante Weber        Briante Weber                     1  100.0  100.0
# Sonny Weems            Sonny Weems                    21   38.1   38.8

# %%
shot_efficiency_stats_unique_df = shot_efficiency_stats_df.drop_duplicates(subset='name', keep='first')
shot_efficiency_stats_unique_df
# Out:
#                           name attempted_field_goals  eFG%   TS%
# Quincy Acy          Quincy Acy                   214  60.0  62.9
# Jordan Adams      Jordan Adams                     6  33.3  42.7
# Steven Adams      Steven Adams                   426  61.3  62.1
# Arron Afflalo    Arron Afflalo                   799  50.0  53.1
# Alexis Ajinça    Alexis Ajinça                   315  47.6  51.4
# ...                        ...                   ...   ...   ...
# Joe Young            Joe Young                   169  39.6  42.8
# Nick Young          Nick Young                   372  44.2  48.3
# Thaddeus Young  Thaddeus Young                   963  51.8  53.3
# Cody Zeller        Cody Zeller                   437  53.0  59.2
# Tyler Zeller      Tyler Zeller                   290  47.6  53.9
#
# [476 rows x 4 columns]

# %%
shot_efficiency_stats_unique_df.loc['Chris Andersen', ['eFG%', 'TS%']] = [55.6, 59.8]
shot_efficiency_stats_unique_df.loc['D.J. Augustin', ['eFG%', 'TS%']] = [52.0, 57.5]
shot_efficiency_stats_unique_df.loc['Chase Budinger', ['eFG%', 'TS%']] = [48.5, 51.4]
shot_efficiency_stats_unique_df.loc['Mario Chalmers', ['eFG%', 'TS%']] = [46.2, 56.1]
shot_efficiency_stats_unique_df.loc['Bryce Cotton', ['eFG%', 'TS%']] = [40.0, 40.0]
shot_efficiency_stats_unique_df.loc['Jared Cunningham', ['eFG%', 'TS%']] = [40.0, 46.4]
shot_efficiency_stats_unique_df.loc['James EnnisIII', ['eFG%', 'TS%']] = [59.3, 62.1]
shot_efficiency_stats_unique_df.loc['Randy Foye', ['eFG%', 'TS%']] = [42.8, 46.1]
shot_efficiency_stats_unique_df.loc['Tim Frazier', ['eFG%', 'TS%']] = [45.4, 49.9]
shot_efficiency_stats_unique_df.loc['Jimmer Fredette', ['eFG%', 'TS%']] = [50.0, 62.5]
shot_efficiency_stats_unique_df.loc['Channing Frye', ['eFG%', 'TS%']] = [56.9, 58.6]
shot_efficiency_stats_unique_df.loc['Erick Green', ['eFG%', 'TS%']] = [42.3, 46.8]
shot_efficiency_stats_unique_df.loc['Jeff Green', ['eFG%', 'TS%']] = [47.0, 51.0]
shot_efficiency_stats_unique_df.loc['P.J. Hairston', ['eFG%', 'TS%']] = [44.1, 47.0]
shot_efficiency_stats_unique_df.loc['Tobias Harris', ['eFG%', 'TS%']] = [51.4, 56.0]
shot_efficiency_stats_unique_df.loc['Justin Holiday', ['eFG%', 'TS%']] = [46.5, 48.9]
shot_efficiency_stats_unique_df.loc['Ryan Hollins', ['eFG%', 'TS%']] = [62.0, 63.6]
shot_efficiency_stats_unique_df.loc['Kris Humphries', ['eFG%', 'TS%']] = [46.8, 51.7] 
shot_efficiency_stats_unique_df.loc['Ersan İlyasova', ['eFG%', 'TS%']] = [49.6, 52.6]
shot_efficiency_stats_unique_df.loc['John Jenkins', ['eFG%', 'TS%']] = [49.4, 52.2]
shot_efficiency_stats_unique_df.loc['Brandon Jennings', ['eFG%', 'TS%']] = [45.2, 49.1] 
shot_efficiency_stats_unique_df.loc['Joe Johnson', ['eFG%', 'TS%']] = [50.9, 53.8] 
shot_efficiency_stats_unique_df.loc['Orlando Johnson', ['eFG%', 'TS%']] = [29.4, 34.6] 
shot_efficiency_stats_unique_df.loc['Sean Kilpatrick', ['eFG%', 'TS%']] = [52.8, 57.6] 
shot_efficiency_stats_unique_df.loc['Ty Lawson', ['eFG%', 'TS%']] = [44.4, 47.6] 
shot_efficiency_stats_unique_df.loc['Courtney Lee', ['eFG%', 'TS%']] = [51.8, 55.1] 
shot_efficiency_stats_unique_df.loc['David Lee', ['eFG%', 'TS%']] = [53.1, 56.8] 
shot_efficiency_stats_unique_df.loc['Shelvin Mack', ['eFG%', 'TS%']] = [48.6, 50.7]
shot_efficiency_stats_unique_df.loc['Kevin Martin', ['eFG%', 'TS%']] = [43.1, 52.0]
shot_efficiency_stats_unique_df.loc['Ray McCallum', ['eFG%', 'TS%']] = [42.8, 44.9]
shot_efficiency_stats_unique_df.loc['Jordan McRae', ['eFG%', 'TS%']] = [50.0, 54.8]
shot_efficiency_stats_unique_df.loc['Andre Miller', ['eFG%', 'TS%']] = [56.6, 60.0]
shot_efficiency_stats_unique_df.loc['Markieff Morris', ['eFG%', 'TS%']] = [45.8, 48.9]
shot_efficiency_stats_unique_df.loc['Steve Novak', ['eFG%', 'TS%']] = [63.9, 65.1]
shot_efficiency_stats_unique_df.loc['Phil Pressey', ['eFG%', 'TS%']] = [41.0, 43.3]
shot_efficiency_stats_unique_df.loc['Brian Roberts', ['eFG%', 'TS%']] = [49.4, 55.2]
shot_efficiency_stats_unique_df.loc['JaKarr Sampson', ['eFG%', 'TS%']] = [46.4, 50.4]
shot_efficiency_stats_unique_df.loc['Ish Smith', ['eFG%', 'TS%']] = [44.0, 46.5]
shot_efficiency_stats_unique_df.loc['Josh Smith', ['eFG%', 'TS%']] = [42.3, 43.9]
shot_efficiency_stats_unique_df.loc['Lance Stephenson', ['eFG%', 'TS%']] = [51.3, 54.8]
shot_efficiency_stats_unique_df.loc['Alex Stepheson', ['eFG%', 'TS%']] = [33.3, 34.1]
shot_efficiency_stats_unique_df.loc['Jarnell Stokes', ['eFG%', 'TS%']] = [60.0, 59.5]
shot_efficiency_stats_unique_df.loc['Jason Thompson', ['eFG%', 'TS%']] = [50.5, 55.8]
shot_efficiency_stats_unique_df.loc['Marcus Thornton', ['eFG%', 'TS%']] = [48.2, 51.1]
shot_efficiency_stats_unique_df.loc['Beno Udrih', ['eFG%', 'TS%']] = [47.2, 49.6]
shot_efficiency_stats_unique_df.loc['Anderson Varejão', ['eFG%', 'TS%']] = [42.7, 47.3]
shot_efficiency_stats_unique_df.loc['Briante Weber', ['eFG%', 'TS%']] = [35.9, 38.0]
shot_efficiency_stats_unique_df.loc['Sonny Weems', ['eFG%', 'TS%']] = [45.0, 45.9]
# Out:
# /tmp/ipykernel_1872917/2297339140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['Chris Andersen', ['eFG%', 'TS%']] = [55.6, 59.8]
# /tmp/ipykernel_1872917/2297339140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['D.J. Augustin', ['eFG%', 'TS%']] = [52.0, 57.5]
# /tmp/ipykernel_1872917/2297339140.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['Chase Budinger', ['eFG%', 'TS%']] = [48.5, 51.4]
# /tmp/ipykernel_1872917/2297339140.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['Mario Chalmers', ['eFG%', 'TS%']] = [46.2, 56.1]
# /tmp/ipykernel_1872917/2297339140.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['Bryce Cotton', ['eFG%', 'TS%']] = [40.0, 40.0]
# /tmp/ipykernel_1872917/2297339140.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['Jared Cunningham', ['eFG%', 'TS%']] = [40.0, 46.4]
# /tmp/ipykernel_1872917/2297339140.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_efficiency_stats_unique_df.loc['James EnnisIII', ['eFG%', 'TS%']] = [59.3, 62.1]

# %%
with open('../pickle_files/clustering1.pkl', 'rb') as f:
    clustering_result = pickle.load(f)
    player_cluster_dict = pickle.load(f)
    players_grouped_by_cluster_dict = pickle.load(f)

# %%
players_grouped_by_cluster_dict[13]
# Out:
# ['Frank Kaminsky',
#  'Chris Bosh',
#  'Kristaps Porzingis',
#  'Carmelo Anthony',
#  'Lance Thomas',
#  'Arron Afflalo',
#  'Bobby Portis',
#  'Derrick Williams',
#  'Aaron Gordon',
#  'Kelly Olynyk',
#  'Draymond Green',
#  'Marcus Morris',
#  'Kawhi Leonard',
#  'Jeff Green',
#  'Andrew Wiggins',
#  'Shabazz Muhammad',
#  'Ryan Anderson',
#  'Kevin Love',
#  'T.J. Warren',
#  'Rudy Gay',
#  'Jon Leuer',
#  'Harrison Barnes',
#  'Spencer Hawes',
#  'Gerald Henderson',
#  'Mike Scott']

# %%
players_grouped_by_cluster_dict[6].remove('Greivis Vasquez')
if "Greivis Vásquez" in name_list:
    print(True)
    players_grouped_by_cluster_dict[6].append("Greivis Vásquez")
# Out:
# True

# %%
players_grouped_by_cluster_dict[5].remove('Manu Ginobili')
if "Manu Ginóbili" in name_list:
    print(True)
    players_grouped_by_cluster_dict[5].append("Manu Ginóbili")
# Out:
# True

# %%
players_grouped_by_cluster_dict[5].remove('JR Smith')
if "J.R. Smith" in name_list:
    print(True)
    players_grouped_by_cluster_dict[5].append("J.R. Smith")
# Out:
# True

# %%
players_grouped_by_cluster_dict[9].remove('PJ Hairston')
if "P.J. Hairston" in name_list:
    print(True)
    players_grouped_by_cluster_dict[9].append("P.J. Hairston")
# Out:
# True

# %%
players_grouped_by_cluster_dict[9].remove('Bojan Bogdanovic')
if "Bojan Bogdanović" in name_list:
    print(True)
    players_grouped_by_cluster_dict[9].append("Bojan Bogdanović")
# Out:
# True

# %%
players_grouped_by_cluster_dict[8].remove('Nikola Mirotic')
if "Nikola Mirotić" in name_list:
    print(True)
    players_grouped_by_cluster_dict[8].append("Nikola Mirotić")
# Out:
# True

# %%
players_grouped_by_cluster_dict[8].remove('Ersan Ilyasova')
if "Ersan İlyasova" in name_list:
    print(True)
    players_grouped_by_cluster_dict[8].append("Ersan İlyasova")
# Out:
# True

# %%
players_grouped_by_cluster_dict[8].remove('Mirza Teletovic')
if "Mirza Teletović" in name_list:
    print(True)
    players_grouped_by_cluster_dict[8].append("Mirza Teletović")
# Out:
# True

# %%
players_grouped_by_cluster_dict[13].remove('Kristaps Porzingis')
if "Kristaps Porziņģis" in name_list:
    print(True)
    players_grouped_by_cluster_dict[13].append("Kristaps Porziņģis")
# Out:
# True

# %%
players_grouped_by_cluster_dict[7].remove('Goran Dragic')
if "Goran Dragić" in name_list:
    print(True)
    players_grouped_by_cluster_dict[7].append("Goran Dragić")
# Out:
# True

# %%
players_grouped_by_cluster_dict[7].remove('Dennis Schroder')
if "Dennis Schröder" in name_list:
    print(True)
    players_grouped_by_cluster_dict[7].append("Dennis Schröder")
# Out:
# True

# %%
players_grouped_by_cluster_dict[3].remove("Johnny O\'Bryant III")
if "Johnny O'Bryant" in name_list:
    print(True)
    players_grouped_by_cluster_dict[3].append("Johnny O'Bryant")
# Out:
# True

# %%
players_grouped_by_cluster_dict[1].remove('Jonas Valanciunas')
if "Jonas Valančiūnas" in name_list:
    print(True)
    players_grouped_by_cluster_dict[1].append("Jonas Valančiūnas")
# Out:
# True

# %%
players_grouped_by_cluster_dict[10].remove('Jose Calderon')
if "José Calderón" in name_list:
    print(True)
    players_grouped_by_cluster_dict[10].append("José Calderón")
# Out:
# True

# %%
players_grouped_by_cluster_dict[10].remove('CJ Miles')
if "C.J. Miles" in name_list:
    print(True)
    players_grouped_by_cluster_dict[10].append("C.J. Miles")
# Out:
# True

# %%
players_grouped_by_cluster_dict[10].remove('Sasha Vujacic')
if "Sasha Vujačić" in name_list:
    print(True)
    players_grouped_by_cluster_dict[10].append("Sasha Vujačić")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('Kevin Seraphin')
if "Kevin Séraphin" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("Kevin Séraphin")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('Nikola Vucevic')
if "Nikola Vučević" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("Nikola Vučević")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('Enes Kanter')
if "Enes Freedom" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("Enes Freedom")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('Nene')
if "Nenê" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("Nenê")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('Nikola Jokic')
if "Nikola Jokić" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("Nikola Jokić")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('JJ Hickson')
if "J.J. Hickson" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("J.J. Hickson")
# Out:
# True

# %%
players_grouped_by_cluster_dict[2].remove('Alexis Ajinca')
if "Alexis Ajinça" in name_list:
    print(True)
    players_grouped_by_cluster_dict[2].append("Alexis Ajinça")
# Out:
# True

# %%
grouped_stats_dict = {}
for k, cluster in players_grouped_by_cluster_dict.items():
    print(k)
    grouped_stats_dict[k] = shot_efficiency_stats_unique_df.loc[cluster, :]
# Out:
# 6
# 5
# 11
# 9
# 8
# 13
# 7
# 3
# 1
# 10
# 2
# 12
# 4

# %%
TS_ranking = {}
for k in range(13):
    n_cluster = k+1
    shot_stats = grouped_stats_dict[n_cluster].sort_values('TS%', ascending=False).iloc[:, 1:4]
    TS_ranking[n_cluster] = shot_stats[shot_stats["attempted_field_goals"] >= 200]

# %%
TS_ranking[1]
# Out:
#                     attempted_field_goals  eFG%   TS%
# Hassan Whiteside                      682  60.6  62.9
# DeAndre Jordan                        508  70.3  62.8
# Cole Aldrich                          225  59.6  62.6
# Andrew Bogut                          279  62.9  62.3
# Steven Adams                          426  61.3  62.1
# Ed Davis                              337  61.1  61.6
# Tristan Thompson                      420  58.8  61.1
# Jonas Valančiūnas                     536  56.5  61.0
# Tyson Chandler                        314  58.3  60.6
# Dwight Howard                         600  62.0  60.4
# Timofey Mozgov                        359  56.7  59.3
# Marcin Gortat                         764  56.7  59.2
# Willie Cauley-Stein                   339  56.3  58.8
# Bismack Biyombo                       288  54.2  58.6
# Rudy Gobert                           354  55.9  58.2
# John Henson                           291  56.4  58.0
# Kenneth Faried                        626  55.8  57.7
# Robin Lopez                           662  53.9  57.4
# Mason Plumlee                         517  51.6  56.4
# Aron Baynes                           384  50.5  56.3
# Greg Monroe                           941  52.2  56.2
# Festus Ezeli                          228  54.8  55.9
# Clint Capela                          397  58.2  55.3
# Kosta Koufos                          444  53.2  54.0
# Jahlil Okafor                         781  50.9  53.6
# Thaddeus Young                        963  51.8  53.3
# Andre Drummond                       1060  52.2  49.9
# Thomas Robinson                       291  44.7  45.3

# %%
TS_ranking[2]
# Out:
#                    attempted_field_goals  eFG%   TS%
# Enes Freedom                         719  58.3  62.6
# Brandon Bass                         317  54.9  61.9
# Ian Mahinmi                          448  58.9  60.3
# Amir Johnson                         426  59.6  60.2
# Gorgui Dieng                         579  53.7  60.1
# Cody Zeller                          437  53.0  59.2
# Karl-Anthony Towns                  1153  55.5  59.0
# Nikola Jokić                         600  53.5  58.2
# Boris Diaw                           383  56.0  58.2
# David West                           448  54.8  57.3
# LaMarcus Aldridge                   1045  51.3  56.5
# Nenê                                 384  54.4  56.4
# Brook Lopez                         1157  51.2  56.2
# Taj Gibson                           500  52.6  55.6
# Derrick Favors                       811  51.5  55.1
# Zaza Pachulia                        470  46.6  55.0
# Nerlens Noel                         587  52.2  54.4
# Jordan Hill                          549  50.6  53.4
# Trevor Booker                        388  50.5  53.3
# Lavoy Allen                          370  51.6  53.2
# Myles Turner                         530  50.1  53.1
# Nikola Vučević                      1046  51.1  53.1
# Pau Gasol                            995  48.1  52.9
# Marc Gasol                           707  46.5  52.8
# Tim Duncan                           441  48.8  52.3
# Zach Randolph                        907  47.9  51.9
# Alexis Ajinça                        315  47.6  51.4
# Al Jefferson                         505  48.5  50.7
# Roy Hibbert                          411  44.3  50.7
# Alex Len                             624  42.4  48.2
# Kevin Séraphin                       205  41.0  43.5

# %%
TS_ranking[3]
# Out:
#                   attempted_field_goals  eFG%   TS%
# Al Horford                         1048  54.7  56.5
# Anthony Davis                      1136  50.8  55.9
# Dwight Powell                       296  49.7  55.7
# Dirk Nowitzki                      1112  50.4  55.5
# Blake Griffin                       603  50.4  54.4
# Larry Nance Jr.                     300  52.8  54.4
# Tyler Zeller                        290  47.6  53.9
# Serge Ibaka                         869  51.3  53.3
# Luis Scola                          598  50.4  52.3
# Kyle O'Quinn                        271  48.5  52.0
# JaMychal Green                      495  48.0  52.0
# Trey Lyles                          436  49.4  51.7
# Darrell Arthur                      489  49.8  51.4
# Jason Smith                         503  48.9  51.3
# Marreese Speights                   456  45.8  50.6
# Andrea Bargnani                     279  46.1  50.0
# Jared Sullinger                     806  45.3  47.6
# Johnny O'Bryant                     209  41.4  44.1

# %%
TS_ranking[4]
# Out:
#                       attempted_field_goals  eFG%   TS%
# Shaun Livingston                        379  53.8  58.1
# Andrew Nicholson                        310  53.7  56.7
# Joffrey Lauvergne                       380  53.0  56.7
# Giannis Antetokounmpo                  1013  52.0  56.6
# Richaun Holmes                          222  53.2  56.4
# Paul Millsap                           1066  50.5  55.6
# DeMarcus Cousins                       1332  47.7  53.8
# Jabari Parker                           899  49.8  53.5
# Terrence Jones                          367  48.6  51.9
# Markieff Morris                         431  45.8  48.9
# Julius Randle                           835  43.5  48.2
# Noah Vonleh                             278  44.1  47.1

# %%
TS_ranking[5]
# Out:
#                          attempted_field_goals  eFG%   TS%
# Stephen Curry                             1598  63.0  66.9
# Kevin Durant                              1381  57.3  63.4
# Chandler Parsons                           651  57.1  58.9
# Omri Casspi                                622  57.1  58.7
# Evan Fournier                              929  54.6  58.7
# Danilo Gallinari                           700  47.2  58.2
# Tyler Johnson                              243  54.1  57.9
# Manu Ginóbili                              435  53.3  57.3
# Gary Harris                                765  53.8  56.6
# Khris Middleton                           1142  50.7  56.0
# Paul George                               1449  49.0  55.7
# George Hill                                739  52.8  55.5
# Courtney Lee                               419  51.8  55.1
# Nicolas Batum                              873  50.6  54.6
# J.R. Smith                                 850  53.5  54.2
# Mario Hezonja                              418  51.3  54.1
# Joe Johnson                                608  50.9  53.8
# Will Barton                                983  48.9  53.5
# Devin Booker                               867  48.0  53.5
# Raul Neto                                  418  50.7  53.0
# Deron Williams                             775  47.7  53.0
# Jeremy Lamb                                510  50.6  52.9
# Kentavious Caldwell-Pope                   960  47.9  52.1
# Kevin Martin                               334  43.1  52.0
# Marcus Thornton                            435  48.2  51.1
# Gerald Green                               587  46.3  49.1
# DeMarre Carroll                            270  47.4  49.0
# Kobe Bryant                               1113  41.7  46.9
# Stanley Johnson                            600  42.8  46.0

# %%
TS_ranking[6]
# Out:
#                     attempted_field_goals  eFG%   TS%
# Lou Williams                          693  48.8  58.4
# Kyle Lowry                           1198  51.6  57.8
# Jerryd Bayless                        437  53.9  56.8
# Damian Lillard                       1474  49.7  56.0
# Kemba Walker                         1331  49.5  55.4
# Zach LaVine                           959  51.6  54.8
# CJ McCollum                          1431  51.7  54.4
# Toney Douglas                         445  50.2  54.3
# Rodney Hood                           972  50.3  54.2
# Ricky Rubio                           586  42.7  52.9
# Jamal Crawford                        939  46.6  52.9
# Mo Williams                           302  49.7  52.7
# Matthew Dellavedova                   511  50.1  52.7
# Brandon Knight                        895  48.2  52.2
# Shane Larkin                          502  48.1  51.5
# John Wall                            1349  46.7  51.0
# Trey Burke                            634  48.3  50.7
# D'Angelo Russell                      956  47.8  50.7
# Jarrett Jack                          358  43.4  50.5
# Monta Ellis                          1021  47.0  50.4
# Raymond Felton                        682  45.0  50.2
# Cameron Payne                         278  47.5  49.0
# Norris Cole                           484  43.9  46.5
# Jameer Nelson                         307  43.8  46.4
# Randy Foye                            333  42.8  46.1
# Shabazz Napier                        201  42.3  46.0

# %%
TS_ranking[7]
# Out:
#                   attempted_field_goals  eFG%   TS%
# James Harden                       1617  51.2  59.8
# Darren Collison                     776  54.2  59.1
# LeBron James                       1416  55.1  58.8
# Chris Paul                         1114  51.7  57.5
# Ramon Sessions                      592  50.3  56.5
# Jimmy Butler                       1035  48.5  56.2
# Isaiah Thomas                      1382  48.8  56.2
# Devin Harris                        374  51.6  55.9
# Gordon Hayward                     1202  49.3  55.9
# Gary Neal                           325  52.8  55.8
# Eric Bledsoe                        492  50.2  55.7
# Russell Westbrook                  1444  48.9  55.4
# Kent Bazemore                       725  51.7  55.1
# Jeff Teague                         988  49.5  55.1
# E'Twaun Moore                       389  54.1  54.8
# Bradley Beal                        799  51.5  54.7
# Leandro Barbosa                     370  51.5  54.5
# Ian Clark                           202  51.5  54.4
# Kyrie Irving                        879  49.6  54.0
# Mike Conley                         696  47.8  53.8
# Goran Dragić                        875  51.3  53.7
# J.J. Barea                          711  51.6  53.6
# Reggie Jackson                     1244  48.2  53.5
# Jeremy Lin                          728  46.4  53.4
# Victor Oladipo                      970  48.9  53.4
# Tyreke Evans                        314  48.6  53.4
# Jrue Holiday                        935  48.5  52.9
# Austin Rivers                       516  49.8  52.3
# Alec Burks                          334  45.8  52.0
# Jordan Clarkson                    1098  48.3  51.6
# Cory Joseph                         585  46.5  51.2
# T.J. McConnell                      464  50.3  51.1
# Dennis Schröder                     781  47.1  51.0
# Rajon Rondo                         782  49.4  50.6
# Rodney Stuckey                      443  43.6  50.4
# Aaron Brooks                        469  47.1  49.4
# Dion Waiters                        706  46.0  49.2
# Jerian Grant                        391  42.2  47.9
# Derrick Rose                       1048  44.8  47.9
# Elfrid Payton                       730  45.6  47.8
# Ty Lawson                           287  44.4  47.6
# Ish Smith                           228  44.0  46.5
# Emmanuel Mudiay                     905  40.4  43.7

# %%
TS_ranking[8]
# Out:
#                  attempted_field_goals  eFG%   TS%
# Jared Dudley                       487  58.1  60.2
# Nemanja Bjelica                    235  57.0  59.4
# Marvin Williams                    747  55.4  58.5
# Mirza Teletović                    777  54.4  57.1
# Nikola Mirotić                     609  51.8  56.4
# Meyers Leonard                     435  54.7  56.1
# Anthony Tolliver                   332  53.3  54.3
# Ersan İlyasova                     508  49.6  52.6
# Wesley Johnson                     515  50.4  51.3
# Matt Barnes                        693  46.7  50.3

# %%
TS_ranking[9]
# Out:
#                   attempted_field_goals  eFG%   TS%
# Richard Jefferson                   312  56.4  58.5
# Joe Ingles                          291  56.5  57.2
# Jae Crowder                         813  51.8  56.5
# Brandon Rush                        260  55.2  56.0
# Patrick Beverley                    594  53.9  55.3
# Trevor Ariza                        859  52.3  55.1
# Bojan Bogdanović                    749  51.9  55.0
# Anthony Morrow                      333  52.7  54.3
# Jason Terry                         376  52.5  54.0
# Patrick Patterson                   493  52.1  53.4
# Al-Farouq Aminu                     719  50.3  53.3
# Hollis Thompson                     680  50.7  52.5
# Garrett Temple                      505  48.6  52.0
# Kelly Oubre Jr.                     211  48.6  50.7
# Markel Brown                        322  45.3  50.0
# Wayne Ellington                     561  47.4  49.8
# Corey Brewer                        552  43.9  48.1
# Tony Snell                          339  45.4  47.8
# Iman Shumpert                       305  44.4  47.5
# P.J. Hairston                       276  44.1  47.0
# Rashad Vaughn                       266  38.5  39.8

# %%
TS_ranking[10]
# Out:
#                   attempted_field_goals  eFG%   TS%
# JJ Redick                           880  59.3  63.2
# Kyle Korver                         616  56.3  57.8
# Allen Crabbe                        678  54.1  57.2
# José Calderón                       455  55.2  57.1
# Eric Gordon                         552  52.1  56.5
# Doug McDermott                      644  53.7  56.1
# Terrence Ross                       626  53.6  55.1
# C.J. Miles                          634  52.1  54.7
# Robert Covington                    712  50.4  54.3
# Patty Mills                         612  52.5  54.1
# Avery Bradley                      1019  52.0  53.8
# Isaiah Canaan                       722  48.2  52.8
# Ronnie Price                        302  49.7  51.7
# Nik Stauskas                        545  48.3  51.7
# Steve Blake                         240  49.6  51.0
# Sasha Vujačić                       277  47.7  50.3
# Marco Belinelli                     635  45.7  50.0
# Danny Green                         561  48.0  49.2
# Langston Galloway                   588  45.8  49.0
# Paul Pierce                         397  45.7  48.9
# Nick Young                          372  44.2  48.3
# O.J. Mayo                           321  45.2  47.4
# Marcus Smart                        529  40.5  46.3

# %%
TS_ranking[11]
# Out:
#                         attempted_field_goals  eFG%   TS%
# Jonathon Simmons                          242  54.1  58.6
# DeMar DeRozan                            1377  46.3  55.0
# Tony Parker                               710  51.2  54.6
# Donald Sloan                              350  49.4  53.6
# James Johnson                             240  51.7  53.2
# Kyle Anderson                             295  48.8  52.8
# Dwyane Wade                              1183  45.9  51.7
# Evan Turner                               753  46.9  51.3
# Jerami Grant                              599  44.8  50.6
# JaKarr Sampson                            202  46.4  50.4
# Michael Carter-Williams                   555  46.6  49.7

# %%
TS_ranking[12]
# Out:
#                    attempted_field_goals  eFG%   TS%
# Klay Thompson                       1386  56.9  59.7
# Thabo Sefolosha                      372  56.2  57.8
# Alonzo Gee                           255  55.1  57.2
# Andre Roberson                       274  55.5  56.6
# Andre Iguodala                       368  55.2  56.5
# Otto Porter Jr.                      717  54.1  56.4
# Tobias Harris                        541  51.4  56.0
# Luol Deng                            745  51.4  54.9
# Maurice Harkless                     411  52.2  54.1
# Dante Cunningham                     412  51.8  54.0
# Wesley Matthews                      854  49.8  53.2
# Ben McLemore                         455  50.2  53.1
# Jonas Jerebko                        286  48.8  53.1
# Vince Carter                         343  47.4  52.0
# P.J. Tucker                          582  46.9  50.6
# Tony Allen                           469  47.4  50.5
# Justise Winslow                      462  45.7  48.9
# Kyle Singler                         221  45.7  48.1
# Charlie Villanueva                   327  45.4  47.3
# Tayshaun Prince                      229  45.4  46.6

# %%
TS_ranking[13]
# Out:
#                    attempted_field_goals  eFG%   TS%
# Kawhi Leonard                       1090  56.5  61.6
# Draymond Green                       819  55.1  58.7
# Mike Scott                           376  55.1  57.5
# Chris Bosh                           767  52.0  57.1
# Kelly Olynyk                         556  53.1  56.1
# Harrison Barnes                      633  53.1  55.9
# Lance Thomas                         382  50.0  55.7
# Jon Leuer                            466  52.6  55.5
# Kevin Love                           977  49.9  55.3
# Derrick Williams                     565  48.8  55.0
# T.J. Warren                          441  53.3  54.9
# Shabazz Muhammad                     681  49.8  54.8
# Ryan Anderson                        929  49.8  54.6
# Andrew Wiggins                      1294  48.1  54.3
# Aaron Gordon                         579  50.9  54.1
# Rudy Gay                            1007  50.0  53.8
# Marcus Morris                        945  49.1  53.1
# Arron Afflalo                        799  50.0  53.1
# Carmelo Anthony                     1307  47.4  53.0
# Gerald Henderson                     529  48.4  52.6
# Kristaps Porziņģis                   886  46.7  51.8
# Frank Kaminsky                       525  47.4  51.3
# Jeff Green                           557  47.0  51.0
# Spencer Hawes                        306  46.7  50.8
# Bobby Portis                         436  44.5  46.9

# %%
combined_df = pd.concat([combined_df.assign(Cluster=f'Cluster {k}') for k, combined_df in TS_ranking.items()], ignore_index=True)
combined_df
# Out:
#     attempted_field_goals  eFG%   TS%     Cluster
# 0                     682  60.6  62.9   Cluster 1
# 1                     508  70.3  62.8   Cluster 1
# 2                     225  59.6  62.6   Cluster 1
# 3                     279  62.9  62.3   Cluster 1
# 4                     426  61.3  62.1   Cluster 1
# ..                    ...   ...   ...         ...
# 292                   886  46.7  51.8  Cluster 13
# 293                   525  47.4  51.3  Cluster 13
# 294                   557  47.0  51.0  Cluster 13
# 295                   306  46.7  50.8  Cluster 13
# 296                   436  44.5  46.9  Cluster 13
#
# [297 rows x 4 columns]

# %%
combined_df.loc[combined_df['Cluster'] == "Cluster 1", 'Cluster Name'] = 'Close-range Big'
combined_df.loc[combined_df['Cluster'] == "Cluster 2", 'Cluster Name'] = 'Mid-range Big'
combined_df.loc[combined_df['Cluster'] == "Cluster 3", 'Cluster Name'] = 'Mid-range All-rounder'
combined_df.loc[combined_df['Cluster'] == "Cluster 4", 'Cluster Name'] = 'Mid-range Slasher'
combined_df.loc[combined_df['Cluster'] == "Cluster 5", 'Cluster Name'] = 'Outside All-rounder'
combined_df.loc[combined_df['Cluster'] == "Cluster 6", 'Cluster Name'] = 'Pull-up Ball-Handler'
combined_df.loc[combined_df['Cluster'] == "Cluster 7", 'Cluster Name'] = 'Drive Ball-Handler'
combined_df.loc[combined_df['Cluster'] == "Cluster 8", 'Cluster Name'] = 'Stretch Four'
combined_df.loc[combined_df['Cluster'] == "Cluster 9", 'Cluster Name'] = 'Corner Shooter'
combined_df.loc[combined_df['Cluster'] == "Cluster 10", 'Cluster Name'] = 'Pure Shooter'
combined_df.loc[combined_df['Cluster'] == "Cluster 11", 'Cluster Name'] = 'Outside Slasher'
combined_df.loc[combined_df['Cluster'] == "Cluster 12", 'Cluster Name'] = 'Drive Shooter'
combined_df.loc[combined_df['Cluster'] == "Cluster 13", 'Cluster Name'] = 'Stretch All-rounder'
combined_df
# Out:
#     attempted_field_goals  eFG%   TS%     Cluster         Cluster Name
# 0                     682  60.6  62.9   Cluster 1      Close-range Big
# 1                     508  70.3  62.8   Cluster 1      Close-range Big
# 2                     225  59.6  62.6   Cluster 1      Close-range Big
# 3                     279  62.9  62.3   Cluster 1      Close-range Big
# 4                     426  61.3  62.1   Cluster 1      Close-range Big
# ..                    ...   ...   ...         ...                  ...
# 292                   886  46.7  51.8  Cluster 13  Stretch All-rounder
# 293                   525  47.4  51.3  Cluster 13  Stretch All-rounder
# 294                   557  47.0  51.0  Cluster 13  Stretch All-rounder
# 295                   306  46.7  50.8  Cluster 13  Stretch All-rounder
# 296                   436  44.5  46.9  Cluster 13  Stretch All-rounder
#
# [297 rows x 5 columns]

# %%
colors = ['red', 'blue', 'green', 'orange', 'gray', 'cyan', 'brown', 'purple', 'pink', 'navy', 'magenta', 'olive', 'black']

# %%
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0), 'axes.linewidth':2})
palette = sns.color_palette("Set2", 13)
g = sns.FacetGrid(combined_df, palette=colors, row="Cluster Name", hue="Cluster Name", aspect=12, height=0.8)
g.map_dataframe(sns.kdeplot, x="TS%", fill=True, alpha=0.85)
g.map_dataframe(sns.kdeplot, x="TS%", color='black')
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color='black', fontsize=13,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, "Cluster Name")
g.fig.subplots_adjust(hspace=-.5)
g.set_titles("")
g.set(yticks=[], xlabel="TS%")
g.despine( left=True)
plt.suptitle('Ridgeline Plot of TS% by Cluster', y=0.95)
# Out:
# Text(0.5, 0.95, 'Ridgeline Plot of TS% by Cluster')

# %%
player_15_16 = pd.read_csv("../meta_data/2015-16-profile.csv")

# %%
for i, h in enumerate(player_15_16["HEIGHT"]):
    feet, inch = h.split("-")
    player_15_16.loc[i, "HEIGHT_CM"] = 30.48*float(feet) + 2.54*float(inch)

# %%
player_15_16
# Out:
#              PLAYER TEAM  AGE HEIGHT  WEIGHT         COLLEGE  \
# 0     Zaza Pachulia  DAL   32   6-11     275             NaN
# 1     Zach Randolph  MEM   34    6-9     260  Michigan State
# 2       Zach LaVine  MIN   21    6-5     189            UCLA
# 3    Xavier Munford  MEM   24    6-3     180    Rhode Island
# 4       Willie Reed  BKN   26   6-10     220       St. Louis
# ..              ...  ...  ...    ...     ...             ...
# 471      Al Horford  ATL   30   6-10     245         Florida
# 472   Adreian Payne  MIN   25   6-10     237  Michigan State
# 473  Aaron Harrison  CHA   21    6-6     210        Kentucky
# 474    Aaron Gordon  ORL   20    6-9     220         Arizona
# 475    Aaron Brooks  CHI   31    6-0     161          Oregon
#
#               COUNTRY DRAFT YEAR DRAFT ROUND DRAFT NUMBER  ...       PTS  REB  \
# 0             Georgia       2003           2           42  ...       650  718
# 1                 USA       2001           1           19  ...  1,040.00  529
# 2                 USA       2014           1           13  ...  1,150.00  228
# 3                 USA       2014         NaN          NaN  ...        80   31
# 4                 USA       2011           0            0  ...    182.00  122
# ..                ...        ...         ...          ...  ...       ...  ...
# 471  Dominican Rep...       2007           1            3  ...  1,249.00  596
# 472               USA       2014           1           15  ...       132  111
# 473               USA  Undrafted   Undrafted    Undrafted  ...     18.00   15
# 474               USA       2014           1            4  ...    719.00  507
# 475               USA       2007           1           26  ...       491  101
#
#      AST  NETRTG   OREB%   DREB%    USG%     TS%    AST% HEIGHT_CM
# 0    128     0.1  12.40%  23.70%  16.30%  55.00%  10.10%    210.82
# 1    142    -1.1   8.80%  18.70%  24.70%  51.90%  12.50%    205.74
# 2    251    -6.2   1.20%   8.90%  22.80%  54.80%  18.70%    195.58
# 3     22    -5.1   1.10%  12.90%  16.80%  48.10%  13.60%    190.50
# 4     10    -7.2  11.30%  17.40%  17.50%  57.90%   3.90%    208.28
# ..   ...     ...     ...     ...     ...     ...     ...       ...
# 471  263     4.2   5.60%  15.80%  20.20%  56.50%  16.50%    208.28
# 472   29   -12.0   4.40%  19.80%  17.50%  42.20%   9.30%    208.28
# 473    2    -3.4   4.50%  11.20%  13.20%  37.10%   3.30%    198.12
# 474  128    -1.4   8.00%  18.90%  16.90%  54.10%  10.30%    205.74
# 475  180     0.0   1.80%   6.80%  22.50%  49.40%  26.50%    182.88
#
# [476 rows x 21 columns]

# %%
player_cluster_df = pd.DataFrame(data= {"PLAYER": player_cluster_dict.keys(), "CLUSTER": player_cluster_dict.values()})

# %%
player_cluster_height_df = pd.merge(player_cluster_df, player_15_16, how="left")

# %%
for k in range(1,14):
    print(player_cluster_height_df[player_cluster_height_df["CLUSTER"]==k]["HEIGHT_CM"].mean())
# Out:
# 210.58909090909088
# 209.946875
# 208.8847619047619
# 206.52153846153848
# 198.62799999999996
# 189.865
# 190.72577777777778
# 205.1957142857143
# 198.60846153846154
# 194.40769230769232
# 199.04363636363635
# 201.50666666666663
# 205.73999999999995
